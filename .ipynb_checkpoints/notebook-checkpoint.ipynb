# %% [markdown]
# # 2020 Election Classification by County

# %% [markdown]
# The Presidential election of 2020 was undoubtedly a major event in U.S. history. We all lived it; 2020 was a year of civil and political unrest, and the reality is that our country is still reeling. We witnessed firsthand how precarious democracy is, and the long-term impact of that election and this country's shifting political landscape is unknown. Political organizers rely heavily on insight regarding vote choice, since they know that big election years do not alone change politics, and much of the legwork happens at the individual and county level.
#
# In this notebook, I'll be modeling the winner of the 2020 presidential election by county using data from the CDC, U.S. Department of Labor, and some demographic datasets from kaggle.
#
# Through various iterations of different classification models focusing on inference (logistic regression, random forest, etc.), normalizing features, and optimizing parameters, I was able to achieve my desired model and identify the most important indicators.

# %% [markdown]
# # Import Libraries and Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
diversity_df = pd.read_csv('data/diversityindex.csv')
unemployment_df = pd.read_csv('data/GeoFRED_Unemployment_Rate_by_County_Percent.csv')
election_df = pd.read_csv('data/president_county_candidate.csv.zip')
states_df = pd.read_csv('data/state_abbrev.csv')
states_elect = pd.read_csv('data/1976-2020-president.csv')

# %%
election_df.head()
# Out:
#       state             county      candidate party  total_votes    won
# 0  Delaware        Kent County      Joe Biden   DEM        44552   True
# 1  Delaware        Kent County   Donald Trump   REP        41009  False
# 2  Delaware        Kent County   Jo Jorgensen   LIB         1044  False
# 3  Delaware        Kent County  Howie Hawkins   GRN          420  False
# 4  Delaware  New Castle County      Joe Biden   DEM       195034   True

# %%
states_elect.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed writein  \
# 0            CARTER, JIMMY                    DEMOCRAT   False
# 1             FORD, GERALD                  REPUBLICAN   False
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                HALL, GUS         COMMUNIST PARTY USE   False
#
#    candidatevotes  totalvotes   version  notes party_simplified
# 0          659170     1182850  20210113    NaN         DEMOCRAT
# 1          504070     1182850  20210113    NaN       REPUBLICAN
# 2            9198     1182850  20210113    NaN            OTHER
# 3            6669     1182850  20210113    NaN            OTHER
# 4            1954     1182850  20210113    NaN            OTHER

# %%
diversity_df.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
#    Asian alone, percent, 2013  \
# 0                        31.1
# 1                        25.2
# 2                        28.8
# 3                        28.2
# 4                        41.4
#
#    Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                2.3
# 1                                                0.2
# 2                                               10.6
# 3                                                1.0
# 4                                                0.7
#
#    Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                               4.8                               14.6
# 1                               2.7                               28.0
# 2                              23.3                               10.7
# 3                               5.2                               22.7
# 4                               3.7                               13.5
#
#    White alone, not Hispanic or Latino, percent, 2013
# 0                                               29.2
# 1                                               26.7
# 2                                               31.5
# 3                                               33.2
# 4                                               12.9

# %%
unemployment_df.head()
# Out:
#     Series ID           Region Name  Region Code  2000  2001  2002  2003  \
# 0  SCABBE1URN  Abbeville County, SC        45001   3.8   6.6   7.7   9.1
# 1  LAACAD0URN     Acadia Parish, LA        22001   5.8   6.0   6.3   6.8
# 2  VAACCO1URN   Accomack County, VA        51001   3.0   3.4   4.2   4.4
# 3  IDADAC1URN        Ada County, ID        16001   3.4   3.9   4.7   4.9
# 4  OKADAI1URN      Adair County, OK        40001   3.5   4.1   4.8   7.8
#
#    2004  2005  2006  ...  2009  2010  2011  2012  2013  2014  2015  2016  \
# 0   8.2   7.7   8.8  ...  14.2  13.6  12.5  10.6   9.5   7.7   6.9   5.5
# 1   5.8   6.1   3.6  ...   6.5   7.3   6.7   6.0   6.0   5.8   6.9   7.4
# 2   4.7   4.7   4.3  ...   6.5   7.9   8.4   7.9   7.2   6.7   5.5   5.0
# 3   4.1   3.3   2.7  ...   8.9   8.3   7.3   6.2   5.2   4.2   3.7   3.3
# 4   6.2   4.8   4.4  ...   8.0  10.5   9.2   9.1   9.8   8.0   6.1   5.9
#
#    2017  2018
# 0   4.6   4.2
# 1   5.9   5.4
# 2   4.9   4.1
# 3   2.8   2.4
# 4   5.0   4.4
#
# [5 rows x 22 columns]

# %%
states_df.head()
# Out:
#         State Abbreviation  Unnamed: 2
# 0     Alabama           AL         NaN
# 1      Alaska           AK         NaN
# 2     Arizona           AZ         NaN
# 3    Arkansas           AR         NaN
# 4  California           CA         NaN

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Change formatting of county names to match election dataset to diversity & unemployment datasets.

# %%
states_dict = dict(zip(states_df['State'], states_df['Abbreviation']))

# %%
election_df['state_abbr'] = election_df['state'].map(states_dict)
election_df.head()
# Out:
#       state             county      candidate party  total_votes    won  \
# 0  Delaware        Kent County      Joe Biden   DEM        44552   True
# 1  Delaware        Kent County   Donald Trump   REP        41009  False
# 2  Delaware        Kent County   Jo Jorgensen   LIB         1044  False
# 3  Delaware        Kent County  Howie Hawkins   GRN          420  False
# 4  Delaware  New Castle County      Joe Biden   DEM       195034   True
#
#   state_abbr
# 0         DE
# 1         DE
# 2         DE
# 3         DE
# 4         DE

# %% [markdown]
# Create list of county names combined with their state's abbreviation.

# %%
def get_county_abbr(list_county, list_abbr):
    list_county_abbr = []
    for i in range(len(list_county)):
        list_county_abbr.append(list_county[i] + ', ' + list_abbr[i])
    return list_county_abbr

# %%
election_df['county_abbr'] = get_county_abbr(election_df['county'], election_df['state_abbr'])
len(election_df['county_abbr'].unique())
# Out:
# 4633

# %%
len(election_df)
# Out:
# 32177

# %% [markdown]
# Subset election dataset to only include the tally for the winning candidate in each county.

# %%
won_elect_df = election_df[election_df['won']==True]
won_elect_df
# Out:
#                       state                county     candidate party  \
# 0                  Delaware           Kent County     Joe Biden   DEM
# 4                  Delaware     New Castle County     Joe Biden   DEM
# 8                  Delaware         Sussex County  Donald Trump   REP
# 12     District of Columbia  District of Columbia     Joe Biden   DEM
# 19     District of Columbia                Ward 2     Joe Biden   DEM
# ...                     ...                   ...           ...   ...
# 32157               Arizona         Graham County  Donald Trump   REP
# 32161               Arizona       Greenlee County  Donald Trump   REP
# 32165               Arizona         La Paz County  Donald Trump   REP
# 32169               Arizona       Maricopa County     Joe Biden   DEM
# 32173               Arizona         Mohave County  Donald Trump   REP
#
#        total_votes   won state_abbr               county_abbr
# 0            44552  True         DE           Kent County, DE
# 4           195034  True         DE     New Castle County, DE
# 8            71230  True         DE         Sussex County, DE
# 12           39041  True         DC  District of Columbia, DC
# 19           29078  True         DC                Ward 2, DC
# ...            ...   ...        ...                       ...
# 32157        10749  True         AZ         Graham County, AZ
# 32161         2433  True         AZ       Greenlee County, AZ
# 32165         5129  True         AZ         La Paz County, AZ
# 32169      1040774  True         AZ       Maricopa County, AZ
# 32173        78535  True         AZ         Mohave County, AZ
#
# [4633 rows x 8 columns]

# %%
len(unemployment_df['Region Name'].values)
# Out:
# 3136

# %%
len(diversity_df['Location'].unique())
# Out:
# 3195

# %% [markdown]
# Merge the won_elect dataset with the diversity dataset.

# %%
df = diversity_df.merge(won_elect_df, how = 'outer', left_on = 'Location', right_on = 'county_abbr')

# %%
df.shape
# Out:
# (4786, 17)

# %%
df.isnull().sum()
# Out:
# Location                                                      1591
# Diversity-Index                                               1591
# Black or African American alone, percent, 2013                1591
# American Indian and Alaska Native alone, percent, 2013        1591
# Asian alone, percent, 2013                                    1591
# Native Hawaiian and Other Pacific Islander alone, percent,    1591
# Two or More Races, percent, 2013                              1591
# Hispanic or Latino, percent, 2013                             1591
# White alone, not Hispanic or Latino, percent, 2013            1591
# state                                                          153
# county                                                         153
# candidate                                                      153
# party                                                          153
# total_votes                                                    153
# won                                                            153
# state_abbr                                                     153
# county_abbr                                                    153
# dtype: int64

# %%
df[df['state'].isnull()]
# Out:
#                             Location  Diversity-Index  \
# 0     Aleutians West Census Area, AK         0.769346
# 4         Aleutians East Borough, AK         0.738867
# 7                             HAWAII         0.731461
# 13      Yakutat City and Borough, AK         0.698748
# 32                        CALIFORNIA         0.674524
# ...                              ...              ...
# 2905                Essex County, VT         0.077938
# 2919             Franklin County, ME         0.076098
# 2940             Somerset County, ME         0.074174
# 2944                Waldo County, ME         0.074163
# 3009              Lincoln County, ME         0.066558
#
#       Black or African American alone, percent, 2013  \
# 0                                                7.4
# 4                                                7.7
# 7                                                2.3
# 13                                               0.9
# 32                                               6.6
# ...                                              ...
# 2905                                             0.4
# 2919                                             0.4
# 2940                                             0.5
# 2944                                             0.5
# 3009                                             0.4
#
#       American Indian and Alaska Native alone, percent, 2013  \
# 0                                                  13.8
# 4                                                  21.8
# 7                                                   0.4
# 13                                                 36.6
# 32                                                  1.7
# ...                                                 ...
# 2905                                                0.6
# 2919                                                0.4
# 2940                                                0.5
# 2944                                                0.5
# 3009                                                0.3
#
#       Asian alone, percent, 2013  \
# 0                           31.1
# 4                           41.4
# 7                           37.7
# 13                           5.6
# 32                          14.1
# ...                          ...
# 2905                         0.4
# 2919                         0.6
# 2940                         0.6
# 2944                         0.5
# 3009                         0.6
#
#       Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                   2.3
# 4                                                   0.7
# 7                                                  10.0
# 13                                                  1.4
# 32                                                  0.5
# ...                                                 ...
# 2905                                                0.0
# 2919                                                0.0
# 2940                                                0.0
# 2944                                                0.1
# 3009                                                0.0
#
#       Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                                  4.8                               14.6
# 4                                  3.7                               13.5
# 7                                 23.1                                9.8
# 13                                15.9                                3.1
# 32                                 3.7                               38.4
# ...                                ...                                ...
# 2905                               1.5                                1.3
# 2919                               1.3                                1.2
# 2940                               1.4                                1.0
# 2944                               1.4                                1.1
# 3009                               1.2                                0.9
#
#       White alone, not Hispanic or Latino, percent, 2013 state county  \
# 0                                                  29.2    NaN    NaN
# 4                                                  12.9    NaN    NaN
# 7                                                  23.0    NaN    NaN
# 13                                                 37.1    NaN    NaN
# 32                                                 39.0    NaN    NaN
# ...                                                 ...    ...    ...
# 2905                                               96.0    NaN    NaN
# 2919                                               96.1    NaN    NaN
# 2940                                               96.2    NaN    NaN
# 2944                                               96.2    NaN    NaN
# 3009                                               96.6    NaN    NaN
#
#      candidate party  total_votes  won state_abbr county_abbr
# 0          NaN   NaN          NaN  NaN        NaN         NaN
# 4          NaN   NaN          NaN  NaN        NaN         NaN
# 7          NaN   NaN          NaN  NaN        NaN         NaN
# 13         NaN   NaN          NaN  NaN        NaN         NaN
# 32         NaN   NaN          NaN  NaN        NaN         NaN
# ...        ...   ...          ...  ...        ...         ...
# 2905       NaN   NaN          NaN  NaN        NaN         NaN
# 2919       NaN   NaN          NaN  NaN        NaN         NaN
# 2940       NaN   NaN          NaN  NaN        NaN         NaN
# 2944       NaN   NaN          NaN  NaN        NaN         NaN
# 3009       NaN   NaN          NaN  NaN        NaN         NaN
#
# [153 rows x 17 columns]

# %% [markdown]
# Fill missing values for states' abbreviations in order to figure out which states are missing data.

# %%
df['state_abbr'] = df.apply(lambda x: x['Location'][-2:] if pd.isnull(x['state_abbr']) else x['state_abbr'], axis=1)

# %%
df[df['state'].isnull()]['state_abbr'].value_counts()
# Out:
# AK    29
# ME    16
# MA    16
# VT    14
# NH    10
# CT     8
# NA     6
# RI     6
# IA     6
# AS     3
# TA     3
# KA     2
# ON     2
# DA     2
# ND     2
# RE     2
# AH     1
# LA     1
# AN     1
# IS     1
# NG     1
# NT     1
# II     1
# EE     1
# TS     1
# PI     1
# NE     1
# EY     1
# WA     1
# ES     1
# CO     1
# SD     1
# HO     1
# HI     1
# VA     1
# RK     1
# NM     1
# DO     1
# IN     1
# UT     1
# IO     1
# KY     1
# Name: state_abbr, dtype: int64

# %% [markdown]
# Fill missing county/town diversity values with state's overall diversity.

# %%
index_AK = df[df['Location']=='ALASKA'].index[0]
AK_diversity = df.iloc[index_AK, 1:9].to_dict()
AK_diversity
# Out:
# {'Diversity-Index': 0.57334,
#  'Black or African American alone, percent, 2013': 3.9,
#  'American Indian and Alaska Native alone, percent, 2013': 14.7,
#  'Asian alone, percent, 2013': 5.8,
#  'Native Hawaiian and Other Pacific Islander alone, percent,': 1.2,
#  'Two or More Races, percent, 2013': 7.1,
#  'Hispanic or Latino, percent, 2013': 6.6,
#  'White alone, not Hispanic or Latino, percent, 2013': 62.5}

# %%
df.loc[df['state']=='Alaska'] = df.loc[df['state']=='Alaska'].fillna(value=AK_diversity)

# %%
len(won_elect_df[won_elect_df['state']=='Maine']['county'].unique())
# Out:
# 498

# %%
index_ME = df[df['Location']=='MAINE'].index[0]
ME_diversity = df.iloc[index_ME, 1:9].to_dict()
df.loc[df['state']=='Maine'] = df.loc[df['state']=='Maine'].fillna(value=ME_diversity)

# %%
index_MA = df[df['Location']=='MASSACHUSETTS'].index[0]
MA_diversity = df.iloc[index_MA, 1:9].to_dict()
df.loc[df['state']=='Massachusetts'] = df.loc[df['state']=='Massachusetts'].fillna(value=MA_diversity)

# %%
index_VT = df[df['Location']=='VERMONT'].index[0]
VT_diversity = df.iloc[index_VT, 1:9].to_dict()
df.loc[df['state']=='Vermont'] = df.loc[df['state']=='Vermont'].fillna(value=VT_diversity)

# %%
index_NH = df[df['Location']=='NEW HAMPSHIRE'].index[0]
NH_diversity = df.iloc[index_NH, 1:9].to_dict()
df.loc[df['state']=='New Hampshire'] = df.loc[df['state']=='New Hampshire'].fillna(value=NH_diversity)

# %%
index_CT = df[df['Location']=='CONNECTICUT'].index[0]
CT_diversity = df.iloc[index_CT, 1:9].to_dict()
df.loc[df['state']=='Connecticut'] = df.loc[df['state']=='Connecticut'].fillna(value=CT_diversity)

# %%
index_RI = df[df['Location']=='RHODE ISLAND'].index[0]
RI_diversity = df.iloc[index_RI, 1:9].to_dict()
df.loc[df['state']=='Rhode Island'] = df.loc[df['state']=='Rhode Island'].fillna(value=RI_diversity)

# %%
df[df['state'].isnull()]
# Out:
#                             Location  Diversity-Index  \
# 0     Aleutians West Census Area, AK         0.769346
# 4         Aleutians East Borough, AK         0.738867
# 7                             HAWAII         0.731461
# 13      Yakutat City and Borough, AK         0.698748
# 32                        CALIFORNIA         0.674524
# ...                              ...              ...
# 2905                Essex County, VT         0.077938
# 2919             Franklin County, ME         0.076098
# 2940             Somerset County, ME         0.074174
# 2944                Waldo County, ME         0.074163
# 3009              Lincoln County, ME         0.066558
#
#       Black or African American alone, percent, 2013  \
# 0                                                7.4
# 4                                                7.7
# 7                                                2.3
# 13                                               0.9
# 32                                               6.6
# ...                                              ...
# 2905                                             0.4
# 2919                                             0.4
# 2940                                             0.5
# 2944                                             0.5
# 3009                                             0.4
#
#       American Indian and Alaska Native alone, percent, 2013  \
# 0                                                  13.8
# 4                                                  21.8
# 7                                                   0.4
# 13                                                 36.6
# 32                                                  1.7
# ...                                                 ...
# 2905                                                0.6
# 2919                                                0.4
# 2940                                                0.5
# 2944                                                0.5
# 3009                                                0.3
#
#       Asian alone, percent, 2013  \
# 0                           31.1
# 4                           41.4
# 7                           37.7
# 13                           5.6
# 32                          14.1
# ...                          ...
# 2905                         0.4
# 2919                         0.6
# 2940                         0.6
# 2944                         0.5
# 3009                         0.6
#
#       Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                   2.3
# 4                                                   0.7
# 7                                                  10.0
# 13                                                  1.4
# 32                                                  0.5
# ...                                                 ...
# 2905                                                0.0
# 2919                                                0.0
# 2940                                                0.0
# 2944                                                0.1
# 3009                                                0.0
#
#       Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                                  4.8                               14.6
# 4                                  3.7                               13.5
# 7                                 23.1                                9.8
# 13                                15.9                                3.1
# 32                                 3.7                               38.4
# ...                                ...                                ...
# 2905                               1.5                                1.3
# 2919                               1.3                                1.2
# 2940                               1.4                                1.0
# 2944                               1.4                                1.1
# 3009                               1.2                                0.9
#
#       White alone, not Hispanic or Latino, percent, 2013 state county  \
# 0                                                  29.2    NaN    NaN
# 4                                                  12.9    NaN    NaN
# 7                                                  23.0    NaN    NaN
# 13                                                 37.1    NaN    NaN
# 32                                                 39.0    NaN    NaN
# ...                                                 ...    ...    ...
# 2905                                               96.0    NaN    NaN
# 2919                                               96.1    NaN    NaN
# 2940                                               96.2    NaN    NaN
# 2944                                               96.2    NaN    NaN
# 3009                                               96.6    NaN    NaN
#
#      candidate party  total_votes  won state_abbr county_abbr
# 0          NaN   NaN          NaN  NaN         AK         NaN
# 4          NaN   NaN          NaN  NaN         AK         NaN
# 7          NaN   NaN          NaN  NaN         II         NaN
# 13         NaN   NaN          NaN  NaN         AK         NaN
# 32         NaN   NaN          NaN  NaN         IA         NaN
# ...        ...   ...          ...  ...        ...         ...
# 2905       NaN   NaN          NaN  NaN         VT         NaN
# 2919       NaN   NaN          NaN  NaN         ME         NaN
# 2940       NaN   NaN          NaN  NaN         ME         NaN
# 2944       NaN   NaN          NaN  NaN         ME         NaN
# 3009       NaN   NaN          NaN  NaN         ME         NaN
#
# [153 rows x 17 columns]

# %% [markdown]
# Identify which rows are state aggregates vs. individual counties.

# %%
def get_overall_status(list_location):
    list_status = []
    for location in list_location:
        if type(location)!=str:
            list_status.append(False)
        elif "," in location:
            list_status.append(False)
        else:
            list_status.append(True)
    return list_status

# %%
df['state_sum'] = get_overall_status(df['Location'])

# %%
df_state_sum = df.loc[df['state_sum']==True]
df_state_sum['Location'] = df_state_sum['Location'].str.title()

# %%
states_dict
# Out:
# {'Alabama': 'AL',
#  'Alaska': 'AK',
#  'Arizona': 'AZ',
#  'Arkansas': 'AR',
#  'California': 'CA',
#  'Colorado': 'CO',
#  'Connecticut': 'CT',
#  'Delaware': 'DE',
#  'District of Columbia': 'DC',
#  'Florida': 'FL',
#  'Georgia': 'GA',
#  'Hawaii': 'HI',
#  'Idaho': 'ID',
#  'Illinois': 'IL',
#  'Indiana': 'IN',
#  'Iowa': 'IA',
#  'Kansas': 'KS',
#  'Kentucky': 'KY',
#  'Louisiana': 'LA',
#  'Maine': 'ME',
#  'Montana': 'MT',
#  'Nebraska': 'NE',
#  'Nevada': 'NV',
#  'New Hampshire': 'NH',
#  'New Jersey': 'NJ',
#  'New Mexico': 'NM',
#  'New York': 'NY',
#  'North Carolina': 'NC',
#  'North Dakota': 'ND',
#  'Ohio': 'OH',
#  'Oklahoma': 'OK',
#  'Oregon': 'OR',
#  'Maryland': 'MD',
#  'Massachusetts': 'MA',
#  'Michigan': 'MI',
#  'Minnesota': 'MN',
#  'Mississippi': 'MS',
#  'Missouri': 'MO',
#  'Pennsylvania': 'PA',
#  'Rhode Island': 'RI',
#  'South Carolina': 'SC',
#  'South Dakota': 'SD',
#  'Tennessee': 'TN',
#  'Texas': 'TX',
#  'Utah': 'UT',
#  'Vermont': 'VT',
#  'Virginia': 'VA',
#  'Washington': 'WA',
#  'West Virginia': 'WV',
#  'Wisconsin': 'WI',
#  'Wyoming': 'WY'}

# %%
df_state_sum['state_abbr'] = df_state_sum['Location'].map(states_dict)

# %%
DC_index = df_state_sum.loc[df_state_sum['Location']=='District Of Columbia'].index[0]

# %%
df_state_sum.loc[DC_index, 'state_abbr'] = 'DC'

# %%
US_index = df_state_sum.loc[df_state_sum['Location']=='United States'].index[0]
df_state_sum.loc[US_index, 'state_abbr'] = 'US'

# %%
df_state_sum.drop(columns = ['state','county','won','county_abbr','state_sum'], inplace=True)

# %% [markdown]
# Clean states_elect data which has state-level tallies to eventually combine with the county-level data from above.

# %%
states_elect.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3  1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4  1976  ALABAMA       AL           1         63        41  US PRESIDENT
#
#                  candidate              party_detailed writein  \
# 0            CARTER, JIMMY                    DEMOCRAT   False
# 1             FORD, GERALD                  REPUBLICAN   False
# 2           MADDOX, LESTER  AMERICAN INDEPENDENT PARTY   False
# 3  BUBAR, BENJAMIN ""BEN""                 PROHIBITION   False
# 4                HALL, GUS         COMMUNIST PARTY USE   False
#
#    candidatevotes  totalvotes   version  notes party_simplified
# 0          659170     1182850  20210113    NaN         DEMOCRAT
# 1          504070     1182850  20210113    NaN       REPUBLICAN
# 2            9198     1182850  20210113    NaN            OTHER
# 3            6669     1182850  20210113    NaN            OTHER
# 4            1954     1182850  20210113    NaN            OTHER

# %%
#Subset to only contain 2020 election
states_elect = states_elect.loc[states_elect['year']==2020]

# %%
#Drop unnecessary columns
states_elect.drop(columns=['year', 'state_fips', 'state_cen', 'state_ic', 'office', 'party_detailed', 'writein', 'version', 'notes'], inplace=True)

# %%
states_elect['party_simplified'].unique()
# Out:
# array(['DEMOCRAT', 'REPUBLICAN', 'LIBERTARIAN', 'OTHER'], dtype=object)

# %%
#Replace candidate names for 'OTHER' party to 'OTHER' to simplify
states_elect.loc[(states_elect['party_simplified'] == 'OTHER'),'candidate']='OTHER'

# %% [markdown]
# Create temporary dataframe grouping states_elect by candidates labeled 'OTHER' by state.

# %%
states_2 = states_elect[states_elect['candidate']=='OTHER'].groupby(['state']).sum()
states_2
# Out:
#                       candidatevotes  totalvotes
# state
# ALABAMA                         7312     2323282
# ALASKA                          6904     1797650
# ARIZONA                         2032    16936630
# ARKANSAS                       21357    12190690
# CALIFORNIA                    196307   140007048
# COLORADO                       58561    65599600
# CONNECTICUT                     8079    20062427
# DELAWARE                        2475     9078228
# DISTRICT OF COLUMBIA            6411     1377424
# FLORIDA                        31356   110674560
# GEORGIA                         2244    79999360
# HAWAII                         11251     2898920
# IDAHO                          10470    10416168
# ILLINOIS                       48393   102573631
# INDIANA                         1951    33364298
# IOWA                           23760    15301170
# KENTUCKY                       11414    25641216
# LOUISIANA                      14607    21480620
# MAINE                          18344     3313220
# MARYLAND                       42105    69851690
# MASSACHUSETTS                  61588    10974015
# MICHIGAN                       25029    44314416
# MINNESOTA                      41053    22940197
# MISSISSIPPI                     9571     7882554
# MISSOURI                       13007    21181734
# MONTANA                           34     2414696
# NEBRASKA                        4671      956383
# NEVADA                         17217     2810752
# NEW HAMPSHIRE                   2372    16123640
# NEW JERSEY                     26067    22746765
# NEW MEXICO                      7872     2771895
# NEW YORK                      125718   181896435
# NORTH CAROLINA                 33059    22099208
# NORTH DAKOTA                    1929      361819
# OHIO                           20634    41455414
# OKLAHOMA                       11798     4682097
# OREGON                         33908     7122963
# RHODE ISLAND                    4529     1550970
# SOUTH CAROLINA                  9536     7542288
# TENNESSEE                      57665    33592361
# TEXAS                          39340   113150560
# UTAH                           24420    16371179
# VERMONT                        11836     7790328
# VIRGINIA                       19765     4460524
# WASHINGTON                     52868    16350524
# WEST VIRGINIA                   2599      794652
# WISCONSIN                      56991    36278451
# WYOMING                         5685     1114012

# %%
#Create dictionary where keys are state names and values are total votes for third party candidates
other_dict = dict(zip(list(states_2.index), states_2['candidatevotes']))

# %%
other_dict
# Out:
# {'ALABAMA': 7312,
#  'ALASKA': 6904,
#  'ARIZONA': 2032,
#  'ARKANSAS': 21357,
#  'CALIFORNIA': 196307,
#  'COLORADO': 58561,
#  'CONNECTICUT': 8079,
#  'DELAWARE': 2475,
#  'DISTRICT OF COLUMBIA': 6411,
#  'FLORIDA': 31356,
#  'GEORGIA': 2244,
#  'HAWAII': 11251,
#  'IDAHO': 10470,
#  'ILLINOIS': 48393,
#  'INDIANA': 1951,
#  'IOWA': 23760,
#  'KENTUCKY': 11414,
#  'LOUISIANA': 14607,
#  'MAINE': 18344,
#  'MARYLAND': 42105,
#  'MASSACHUSETTS': 61588,
#  'MICHIGAN': 25029,
#  'MINNESOTA': 41053,
#  'MISSISSIPPI': 9571,
#  'MISSOURI': 13007,
#  'MONTANA': 34,
#  'NEBRASKA': 4671,
#  'NEVADA': 17217,
#  'NEW HAMPSHIRE': 2372,
#  'NEW JERSEY': 26067,
#  'NEW MEXICO': 7872,
#  'NEW YORK': 125718,
#  'NORTH CAROLINA': 33059,
#  'NORTH DAKOTA': 1929,
#  'OHIO': 20634,
#  'OKLAHOMA': 11798,
#  'OREGON': 33908,
#  'RHODE ISLAND': 4529,
#  'SOUTH CAROLINA': 9536,
#  'TENNESSEE': 57665,
#  'TEXAS': 39340,
#  'UTAH': 24420,
#  'VERMONT': 11836,
#  'VIRGINIA': 19765,
#  'WASHINGTON': 52868,
#  'WEST VIRGINIA': 2599,
#  'WISCONSIN': 56991,
#  'WYOMING': 5685}

# %%
def get_others(dict_, list_states, list_candidates, list_votes):
    votes = []
    for i in range(len(list_states)):
        if list_candidates[i]=='OTHER':
            votes.append(dict_[list_states[i]])
        else:
            votes.append(list_votes[i])
    return votes

# %%
states_elect['candidatevotes'] = get_others(other_dict, list(states_elect['state']), list(states_elect['candidate']), list(states_elect['candidatevotes']))

# %%
states_elect.drop_duplicates(inplace = True)

# %%
#Create dictionary where keys are state names and values are total votes for the winning candidate

win_tallies = list(states_elect.groupby('state')['candidatevotes'].max())
states = list(states_elect['state'].unique())
win_dict = dict(zip(states, win_tallies))
win_dict
# Out:
# {'ALABAMA': 1441170,
#  'ALASKA': 189951,
#  'ARIZONA': 1672143,
#  'ARKANSAS': 760647,
#  'CALIFORNIA': 11110250,
#  'COLORADO': 1804352,
#  'CONNECTICUT': 1080831,
#  'DELAWARE': 296268,
#  'DISTRICT OF COLUMBIA': 317323,
#  'FLORIDA': 5668731,
#  'GEORGIA': 2473633,
#  'HAWAII': 366130,
#  'IDAHO': 554119,
#  'ILLINOIS': 3471915,
#  'INDIANA': 1729519,
#  'IOWA': 897672,
#  'KANSAS': 771406,
#  'KENTUCKY': 1326646,
#  'LOUISIANA': 1255776,
#  'MAINE': 435072,
#  'MARYLAND': 1985023,
#  'MASSACHUSETTS': 2382202,
#  'MICHIGAN': 2804040,
#  'MINNESOTA': 1717077,
#  'MISSISSIPPI': 756764,
#  'MISSOURI': 1718736,
#  'MONTANA': 343602,
#  'NEBRASKA': 556846,
#  'NEVADA': 703486,
#  'NEW HAMPSHIRE': 424921,
#  'NEW JERSEY': 2608335,
#  'NEW MEXICO': 501614,
#  'NEW YORK': 5230985,
#  'NORTH CAROLINA': 2758773,
#  'NORTH DAKOTA': 235595,
#  'OHIO': 3154834,
#  'OKLAHOMA': 1020280,
#  'OREGON': 1340383,
#  'PENNSYLVANIA': 3458229,
#  'RHODE ISLAND': 307486,
#  'SOUTH CAROLINA': 1385103,
#  'SOUTH DAKOTA': 261043,
#  'TENNESSEE': 1852475,
#  'TEXAS': 5890347,
#  'UTAH': 865140,
#  'VERMONT': 242820,
#  'VIRGINIA': 2413568,
#  'WASHINGTON': 2369612,
#  'WEST VIRGINIA': 545382,
#  'WISCONSIN': 1630866,
#  'WYOMING': 193559}

# %%
#Create 'winner_tally' column to map win_dict to

states_elect['winner_tally'] = states_elect['state']
states_elect
# Out:
#           state state_po            candidate  candidatevotes  totalvotes  \
# 3740    ALABAMA       AL  BIDEN, JOSEPH R. JR          849624     2323282
# 3741    ALABAMA       AL     TRUMP, DONALD J.         1441170     2323282
# 3742    ALABAMA       AL        JORGENSEN, JO           25176     2323282
# 3743    ALABAMA       AL                OTHER            7312     2323282
# 3744     ALASKA       AK  BIDEN, JOSEPH R. JR          153778      359530
# ...         ...      ...                  ...             ...         ...
# 4269  WISCONSIN       WI                OTHER           56991     3298041
# 4280    WYOMING       WY  BIDEN, JOSEPH R. JR           73491      278503
# 4281    WYOMING       WY     TRUMP, DONALD J.          193559      278503
# 4282    WYOMING       WY        JORGENSEN, JO            5768      278503
# 4283    WYOMING       WY                OTHER            5685      278503
#
#      party_simplified winner_tally
# 3740         DEMOCRAT      ALABAMA
# 3741       REPUBLICAN      ALABAMA
# 3742      LIBERTARIAN      ALABAMA
# 3743            OTHER      ALABAMA
# 3744         DEMOCRAT       ALASKA
# ...               ...          ...
# 4269            OTHER    WISCONSIN
# 4280         DEMOCRAT      WYOMING
# 4281       REPUBLICAN      WYOMING
# 4282      LIBERTARIAN      WYOMING
# 4283            OTHER      WYOMING
#
# [199 rows x 7 columns]

# %%
#Map win_dict to winner_tally
states_elect['winner_tally'] = states_elect['winner_tally'].map(win_dict)

# %%
#Change name of column to 'winner'
states_elect['winner'] = states_elect['winner_tally']

# %% [markdown]
# Replace tally with boolean for if the winner tally matches the candidate votes to more easily identify the winner.

# %%
states_elect['winner'] = np.where(states_elect['candidatevotes']==states_elect['winner_tally'], True, False)
states_elect.drop('winner_tally', axis=1, inplace=True)
states_elect
# Out:
#           state state_po            candidate  candidatevotes  totalvotes  \
# 3740    ALABAMA       AL  BIDEN, JOSEPH R. JR          849624     2323282
# 3741    ALABAMA       AL     TRUMP, DONALD J.         1441170     2323282
# 3742    ALABAMA       AL        JORGENSEN, JO           25176     2323282
# 3743    ALABAMA       AL                OTHER            7312     2323282
# 3744     ALASKA       AK  BIDEN, JOSEPH R. JR          153778      359530
# ...         ...      ...                  ...             ...         ...
# 4269  WISCONSIN       WI                OTHER           56991     3298041
# 4280    WYOMING       WY  BIDEN, JOSEPH R. JR           73491      278503
# 4281    WYOMING       WY     TRUMP, DONALD J.          193559      278503
# 4282    WYOMING       WY        JORGENSEN, JO            5768      278503
# 4283    WYOMING       WY                OTHER            5685      278503
#
#      party_simplified  winner
# 3740         DEMOCRAT   False
# 3741       REPUBLICAN    True
# 3742      LIBERTARIAN   False
# 3743            OTHER   False
# 3744         DEMOCRAT   False
# ...               ...     ...
# 4269            OTHER   False
# 4280         DEMOCRAT   False
# 4281       REPUBLICAN    True
# 4282      LIBERTARIAN   False
# 4283            OTHER   False
#
# [199 rows x 7 columns]

# %%
#Create a 'vote_ratio' column with the proportion of the vote won by each candidate.

states_elect['vote_ratio'] = states_elect['candidatevotes']/states_elect['totalvotes']
states_elect
# Out:
#           state state_po            candidate  candidatevotes  totalvotes  \
# 3740    ALABAMA       AL  BIDEN, JOSEPH R. JR          849624     2323282
# 3741    ALABAMA       AL     TRUMP, DONALD J.         1441170     2323282
# 3742    ALABAMA       AL        JORGENSEN, JO           25176     2323282
# 3743    ALABAMA       AL                OTHER            7312     2323282
# 3744     ALASKA       AK  BIDEN, JOSEPH R. JR          153778      359530
# ...         ...      ...                  ...             ...         ...
# 4269  WISCONSIN       WI                OTHER           56991     3298041
# 4280    WYOMING       WY  BIDEN, JOSEPH R. JR           73491      278503
# 4281    WYOMING       WY     TRUMP, DONALD J.          193559      278503
# 4282    WYOMING       WY        JORGENSEN, JO            5768      278503
# 4283    WYOMING       WY                OTHER            5685      278503
#
#      party_simplified  winner  vote_ratio
# 3740         DEMOCRAT   False    0.365700
# 3741       REPUBLICAN    True    0.620316
# 3742      LIBERTARIAN   False    0.010836
# 3743            OTHER   False    0.003147
# 3744         DEMOCRAT   False    0.427720
# ...               ...     ...         ...
# 4269            OTHER   False    0.017280
# 4280         DEMOCRAT   False    0.263879
# 4281       REPUBLICAN    True    0.694998
# 4282      LIBERTARIAN   False    0.020711
# 4283            OTHER   False    0.020413
#
# [199 rows x 8 columns]

# %% [markdown]
# Subset states_elect to just contain the winners.

# %%
states_winners = states_elect[states_elect['winner']==True]

# %%
states_winners['state'] = states_winners['state'].str.title()

# %%
states_winners.head()
# Out:
#            state state_po            candidate  candidatevotes  totalvotes  \
# 3741     Alabama       AL     TRUMP, DONALD J.         1441170     2323282
# 3745      Alaska       AK     TRUMP, DONALD J.          189951      359530
# 3752     Arizona       AZ  BIDEN, JOSEPH R. JR         1672143     3387326
# 3771    Arkansas       AR     TRUMP, DONALD J.          760647     1219069
# 3773  California       CA  BIDEN, JOSEPH R. JR        11110250    17500881
#
#      party_simplified  winner  vote_ratio
# 3741       REPUBLICAN    True    0.620316
# 3745       REPUBLICAN    True    0.528331
# 3752         DEMOCRAT    True    0.493647
# 3771       REPUBLICAN    True    0.623957
# 3773         DEMOCRAT    True    0.634839

# %% [markdown]
# Merge states_elect with df_state_sum.

# %%
states_merged = states_elect.merge(df_state_sum, how='outer', right_on='state_abbr', left_on='state_po')

# %%
states_merged.drop(['Location', 'candidate_y', 'party', 'total_votes', 'state_abbr'], axis=1, inplace=True)

# %% [markdown]
# Merge new states_merged with df and subset to only contain winners.

# %%
merged_counties = df.merge(states_merged, how='outer', left_on='state_abbr', right_on='state_po')
merged_counties = merged_counties[merged_counties['winner']==True]

# %%
merged_counties
# Out:
#                              Location  Diversity-Index_x  \
# 1      Aleutians West Census Area, AK           0.769346
# 5          Aleutians East Borough, AK           0.738867
# 9        Yakutat City and Borough, AK           0.698748
# 13          Kodiak Island Borough, AK           0.665746
# 17            Bristol Bay Borough, AK           0.648271
# ...                               ...                ...
# 18612                             NaN           0.115582
# 18616                             NaN           0.115582
# 18620                             NaN           0.115582
# 18624                             NaN           0.115582
# 18628                             NaN           0.115582
#
#        Black or African American alone, percent, 2013_x  \
# 1                                                   7.4
# 5                                                   7.7
# 9                                                   0.9
# 13                                                  1.3
# 17                                                  0.0
# ...                                                 ...
# 18612                                               1.4
# 18616                                               1.4
# 18620                                               1.4
# 18624                                               1.4
# 18628                                               1.4
#
#        American Indian and Alaska Native alone, percent, 2013_x  \
# 1                                                   13.8
# 5                                                   21.8
# 9                                                   36.6
# 13                                                  13.0
# 17                                                  33.8
# ...                                                  ...
# 18612                                                0.7
# 18616                                                0.7
# 18620                                                0.7
# 18624                                                0.7
# 18628                                                0.7
#
#        Asian alone, percent, 2013_x  \
# 1                              31.1
# 5                              41.4
# 9                               5.6
# 13                             20.3
# 17                              1.1
# ...                             ...
# 18612                           1.1
# 18616                           1.1
# 18620                           1.1
# 18624                           1.1
# 18628                           1.1
#
#        Native Hawaiian and Other Pacific Islander alone, percent,_x  \
# 1                                                    2.3
# 5                                                    0.7
# 9                                                    1.4
# 13                                                   1.0
# 17                                                   0.3
# ...                                                  ...
# 18612                                                0.0
# 18616                                                0.0
# 18620                                                0.0
# 18624                                                0.0
# 18628                                                0.0
#
#        Two or More Races, percent, 2013_x  \
# 1                                     4.8
# 5                                     3.7
# 9                                    15.9
# 13                                    6.8
# 17                                   17.5
# ...                                   ...
# 18612                                 1.6
# 18616                                 1.6
# 18620                                 1.6
# 18624                                 1.6
# 18628                                 1.6
#
#        Hispanic or Latino, percent, 2013_x  \
# 1                                     14.6
# 5                                     13.5
# 9                                      3.1
# 13                                     8.4
# 17                                     3.9
# ...                                    ...
# 18612                                  1.4
# 18616                                  1.4
# 18620                                  1.4
# 18624                                  1.4
# 18628                                  1.4
#
#        White alone, not Hispanic or Latino, percent, 2013_x state_x  ...  \
# 1                                                   29.2        NaN  ...
# 5                                                   12.9        NaN  ...
# 9                                                   37.1        NaN  ...
# 13                                                  51.4        NaN  ...
# 17                                                  45.3        NaN  ...
# ...                                                  ...        ...  ...
# 18612                                               94.0      Maine  ...
# 18616                                               94.0      Maine  ...
# 18620                                               94.0      Maine  ...
# 18624                                               94.0      Maine  ...
# 18628                                               94.0      Maine  ...
#
#       winner vote_ratio Diversity-Index_y  \
# 1       True   0.528331          0.573340
# 5       True   0.528331          0.573340
# 9       True   0.528331          0.573340
# 13      True   0.528331          0.573340
# 17      True   0.528331          0.573340
# ...      ...        ...               ...
# 18612   True   0.525256          0.115582
# 18616   True   0.525256          0.115582
# 18620   True   0.525256          0.115582
# 18624   True   0.525256          0.115582
# 18628   True   0.525256          0.115582
#
#        Black or African American alone, percent, 2013_y  \
# 1                                                   3.9
# 5                                                   3.9
# 9                                                   3.9
# 13                                                  3.9
# 17                                                  3.9
# ...                                                 ...
# 18612                                               1.4
# 18616                                               1.4
# 18620                                               1.4
# 18624                                               1.4
# 18628                                               1.4
#
#       American Indian and Alaska Native alone, percent, 2013_y  \
# 1                                                   14.7
# 5                                                   14.7
# 9                                                   14.7
# 13                                                  14.7
# 17                                                  14.7
# ...                                                  ...
# 18612                                                0.7
# 18616                                                0.7
# 18620                                                0.7
# 18624                                                0.7
# 18628                                                0.7
#
#       Asian alone, percent, 2013_y  \
# 1                              5.8
# 5                              5.8
# 9                              5.8
# 13                             5.8
# 17                             5.8
# ...                            ...
# 18612                          1.1
# 18616                          1.1
# 18620                          1.1
# 18624                          1.1
# 18628                          1.1
#
#       Native Hawaiian and Other Pacific Islander alone, percent,_y  \
# 1                                                    1.2
# 5                                                    1.2
# 9                                                    1.2
# 13                                                   1.2
# 17                                                   1.2
# ...                                                  ...
# 18612                                                0.0
# 18616                                                0.0
# 18620                                                0.0
# 18624                                                0.0
# 18628                                                0.0
#
#       Two or More Races, percent, 2013_y Hispanic or Latino, percent, 2013_y  \
# 1                                    7.1                                 6.6
# 5                                    7.1                                 6.6
# 9                                    7.1                                 6.6
# 13                                   7.1                                 6.6
# 17                                   7.1                                 6.6
# ...                                  ...                                 ...
# 18612                                1.6                                 1.4
# 18616                                1.6                                 1.4
# 18620                                1.6                                 1.4
# 18624                                1.6                                 1.4
# 18628                                1.6                                 1.4
#
#       White alone, not Hispanic or Latino, percent, 2013_y
# 1                                                   62.5
# 5                                                   62.5
# 9                                                   62.5
# 13                                                  62.5
# 17                                                  62.5
# ...                                                  ...
# 18612                                               94.0
# 18616                                               94.0
# 18620                                               94.0
# 18624                                               94.0
# 18628                                               94.0
#
# [4751 rows x 34 columns]

# %%
merged_counties.dropna(subset=['Diversity-Index_x'], inplace=True)
merged_counties.isnull().sum()
# Out:
# Location                                                        1580
# Diversity-Index_x                                                  0
# Black or African American alone, percent, 2013_x                   0
# American Indian and Alaska Native alone, percent, 2013_x           0
# Asian alone, percent, 2013_x                                       0
# Native Hawaiian and Other Pacific Islander alone, percent,_x       0
# Two or More Races, percent, 2013_x                                 0
# Hispanic or Latino, percent, 2013_x                                0
# White alone, not Hispanic or Latino, percent, 2013_x               0
# state_x                                                          118
# county                                                           118
# candidate                                                        118
# party                                                            118
# total_votes                                                      118
# won                                                              118
# state_abbr                                                         0
# county_abbr                                                      118
# state_sum                                                          0
# state_y                                                            0
# state_po                                                           0
# candidate_x                                                        0
# candidatevotes                                                     0
# totalvotes                                                         0
# party_simplified                                                   0
# winner                                                             0
# vote_ratio                                                         0
# Diversity-Index_y                                                  0
# Black or African American alone, percent, 2013_y                   0
# American Indian and Alaska Native alone, percent, 2013_y           0
# Asian alone, percent, 2013_y                                       0
# Native Hawaiian and Other Pacific Islander alone, percent,_y       0
# Two or More Races, percent, 2013_y                                 0
# Hispanic or Latino, percent, 2013_y                                0
# White alone, not Hispanic or Latino, percent, 2013_y               0
# dtype: int64

# %%
merged_counties.drop_duplicates(subset=['Diversity-Index_x', 'Diversity-Index_y'], inplace=True)

# %%
merged_counties[merged_counties['Location'].isnull()]
# Out:
#       Location  Diversity-Index_x  \
# 117        NaN           0.573340
# 5092       NaN           0.414346
# 12480      NaN           0.478890
# 13583      NaN           0.407071
# 14590      NaN           0.158854
# 15592      NaN           0.119187
# 16640      NaN           0.115582
#
#        Black or African American alone, percent, 2013_x  \
# 117                                                 3.9
# 5092                                                8.1
# 12480                                              11.3
# 13583                                               7.5
# 14590                                               1.5
# 15592                                               1.2
# 16640                                               1.4
#
#        American Indian and Alaska Native alone, percent, 2013_x  \
# 117                                                 14.7
# 5092                                                 0.5
# 12480                                                0.5
# 13583                                                0.9
# 14590                                                0.3
# 15592                                                0.4
# 16640                                                0.7
#
#        Asian alone, percent, 2013_x  \
# 117                             5.8
# 5092                            6.0
# 12480                           4.3
# 13583                           3.3
# 14590                           2.4
# 15592                           1.4
# 16640                           1.1
#
#        Native Hawaiian and Other Pacific Islander alone, percent,_x  \
# 117                                                  1.2
# 5092                                                 0.1
# 12480                                                0.1
# 13583                                                0.2
# 14590                                                0.0
# 15592                                                0.0
# 16640                                                0.0
#
#        Two or More Races, percent, 2013_x  \
# 117                                   7.1
# 5092                                  2.1
# 12480                                 2.1
# 13583                                 2.5
# 14590                                 1.6
# 15592                                 1.8
# 16640                                 1.6
#
#        Hispanic or Latino, percent, 2013_x  \
# 117                                    6.6
# 5092                                  10.5
# 12480                                 14.7
# 13583                                 13.6
# 14590                                  3.2
# 15592                                  1.7
# 16640                                  1.4
#
#        White alone, not Hispanic or Latino, percent, 2013_x        state_x  \
# 117                                                 62.5            Alaska
# 5092                                                75.1     Massachusetts
# 12480                                               69.6       Connecticut
# 13583                                               75.3      Rhode Island
# 14590                                               91.6     New Hampshire
# 15592                                               93.8           Vermont
# 16640                                               94.0             Maine
#
#        ... winner vote_ratio Diversity-Index_y  \
# 117    ...   True   0.528331          0.573340
# 5092   ...   True   0.651230          0.414346
# 12480  ...   True   0.592607          0.478890
# 13583  ...   True   0.594762          0.407071
# 14590  ...   True   0.527078          0.158854
# 15592  ...   True   0.654558          0.119187
# 16640  ...   True   0.525256          0.115582
#
#        Black or African American alone, percent, 2013_y  \
# 117                                                 3.9
# 5092                                                8.1
# 12480                                              11.3
# 13583                                               7.5
# 14590                                               1.5
# 15592                                               1.2
# 16640                                               1.4
#
#       American Indian and Alaska Native alone, percent, 2013_y  \
# 117                                                 14.7
# 5092                                                 0.5
# 12480                                                0.5
# 13583                                                0.9
# 14590                                                0.3
# 15592                                                0.4
# 16640                                                0.7
#
#       Asian alone, percent, 2013_y  \
# 117                            5.8
# 5092                           6.0
# 12480                          4.3
# 13583                          3.3
# 14590                          2.4
# 15592                          1.4
# 16640                          1.1
#
#       Native Hawaiian and Other Pacific Islander alone, percent,_y  \
# 117                                                  1.2
# 5092                                                 0.1
# 12480                                                0.1
# 13583                                                0.2
# 14590                                                0.0
# 15592                                                0.0
# 16640                                                0.0
#
#       Two or More Races, percent, 2013_y Hispanic or Latino, percent, 2013_y  \
# 117                                  7.1                                 6.6
# 5092                                 2.1                                10.5
# 12480                                2.1                                14.7
# 13583                                2.5                                13.6
# 14590                                1.6                                 3.2
# 15592                                1.8                                 1.7
# 16640                                1.6                                 1.4
#
#       White alone, not Hispanic or Latino, percent, 2013_y
# 117                                                 62.5
# 5092                                                75.1
# 12480                                               69.6
# 13583                                               75.3
# 14590                                               91.6
# 15592                                               93.8
# 16640                                               94.0
#
# [7 rows x 34 columns]

# %%
merged_counties.loc[(merged_counties['state_x']=='Alaska'), 'Location']='Alaska'
merged_counties.loc[(merged_counties['state_x']=='Massachusetts'), 'Location']='Massachusetts'
merged_counties.loc[(merged_counties['state_x']=='Connecticut'), 'Location']='Connecticut'
merged_counties.loc[(merged_counties['state_x']=='Rhode Island'), 'Location']='Rhode Island'
merged_counties.loc[(merged_counties['state_x']=='New Hampshire'), 'Location']='New Hampshire'
merged_counties.loc[(merged_counties['state_x']=='Vermont'), 'Location']='Vermont'
merged_counties.loc[(merged_counties['state_x']=='Maine'), 'Location']='Maine'

# %%
merged_counties.dropna(subset=['state_x'], inplace=True)

# %%
merged_counties.columns
# Out:
# Index(['Location', 'Diversity-Index_x',
#        'Black or African American alone, percent, 2013_x',
#        'American Indian and Alaska Native alone, percent, 2013_x',
#        'Asian alone, percent, 2013_x',
#        'Native Hawaiian and Other Pacific Islander alone, percent,_x',
#        'Two or More Races, percent, 2013_x',
#        'Hispanic or Latino, percent, 2013_x',
#        'White alone, not Hispanic or Latino, percent, 2013_x', 'state_x',
#        'county', 'candidate', 'party', 'total_votes', 'won', 'state_abbr',
#        'county_abbr', 'state_sum', 'state_y', 'state_po', 'candidate_x',
#        'candidatevotes', 'totalvotes', 'party_simplified', 'winner',
#        'vote_ratio', 'Diversity-Index_y',
#        'Black or African American alone, percent, 2013_y',
#        'American Indian and Alaska Native alone, percent, 2013_y',
#        'Asian alone, percent, 2013_y',
#        'Native Hawaiian and Other Pacific Islander alone, percent,_y',
#        'Two or More Races, percent, 2013_y',
#        'Hispanic or Latino, percent, 2013_y',
#        'White alone, not Hispanic or Latino, percent, 2013_y'],
#       dtype='object')

# %%
merged_counties.drop(merged_counties.iloc[:, -7:], inplace=True, axis = 1)
merged_counties.drop(columns=['won', 'county', 'state_po', 'winner', 'state_sum', 'county_abbr', 'state_y', 'party', 'party_simplified'], inplace=True)

# %%
merged_counties['candidate'].value_counts()
# Out:
# Donald Trump    2561
# Joe Biden        486
# Name: candidate, dtype: int64

# %%
merged_counties['candidate_x'].value_counts()
# Out:
# TRUMP, DONALD J.       1963
# BIDEN, JOSEPH R. JR    1084
# Name: candidate_x, dtype: int64

# %% [markdown]
# Clean column names.

# %%
mapper_dict = {'Diversity-Index_x':'Loc_DI',
              'Black or African American alone, percent, 2013_x':'Black or African American alone, percent',
       'American Indian and Alaska Native alone, percent, 2013_x':'American Indian and Alaska Native alone, percent',
       'Asian alone, percent, 2013_x':'Asian alone, percent',
       'Native Hawaiian and Other Pacific Islander alone, percent,_x':'Native Hawaiian and Other Pacific Islander alone, percent',
       'Two or More Races, percent, 2013_x':'Two or More Races, percent',
       'Hispanic or Latino, percent, 2013_x':'Hispanic or Latino, percent',
       'White alone, not Hispanic or Latino, percent, 2013_x':'White alone, not Hispanic or Latino, percent',
        'state_x':'state',
        'candidate':'loc_winner',
        'candidate_x':'won_loc_and_state',
        'Diversity-Index_y':'state_DI',
        'vote_ratio':'win_ratio'}
merged_counties.rename(mapper=mapper_dict, inplace=True, axis=1)

# %% [markdown]
# Reformat candidate names to match all columns and change column 'won_loc_and_state' values to True/False based on if the location candidate matches the state candidate.

# %%
candidate_dict = {'TRUMP, DONALD J.':'Donald Trump', 'BIDEN, JOSEPH R. JR':'Joe Biden'}
merged_counties['won_loc_and_state']=merged_counties['won_loc_and_state'].map(candidate_dict)

# %%
merged_counties['won_loc_and_state'] = np.where(
    merged_counties['loc_winner']==merged_counties['won_loc_and_state'], 
    True, 
    False)

# %% [markdown]
# Make new column 'DI_diff' with the difference between the location's diversity index and its state's diversity index.

# %%
merged_counties['DI_diff']=merged_counties['Loc_DI']-merged_counties['state_DI']
merged_counties
# Out:
#                      Location    Loc_DI  \
# 117                    Alaska  0.573340
# 276         Queens County, NY  0.742224
# 280          Kings County, NY  0.692349
# 284       New York County, NY  0.658205
# 288    Westchester County, NY  0.605911
# ...                       ...       ...
# 14534        Tyler County, WV  0.039485
# 14538      Lincoln County, WV  0.035585
# 14590           New Hampshire  0.158854
# 15592                 Vermont  0.119187
# 16640                   Maine  0.115582
#
#        Black or African American alone, percent  \
# 117                                         3.9
# 276                                        20.9
# 280                                        35.4
# 284                                        18.4
# 288                                        15.9
# ...                                         ...
# 14534                                       0.3
# 14538                                       0.2
# 14590                                       1.5
# 15592                                       1.2
# 16640                                       1.4
#
#        American Indian and Alaska Native alone, percent  Asian alone, percent  \
# 117                                                14.7                   5.8
# 276                                                 1.3                  25.2
# 280                                                 1.0                  11.7
# 284                                                 1.2                  12.1
# 288                                                 0.8                   6.1
# ...                                                 ...                   ...
# 14534                                               0.2                   0.2
# 14538                                               0.1                   0.1
# 14590                                               0.3                   2.4
# 15592                                               0.4                   1.4
# 16640                                               0.7                   1.1
#
#        Native Hawaiian and Other Pacific Islander alone, percent  \
# 117                                                  1.2
# 276                                                  0.2
# 280                                                  0.1
# 284                                                  0.2
# 288                                                  0.1
# ...                                                  ...
# 14534                                                0.0
# 14538                                                0.0
# 14590                                                0.0
# 15592                                                0.0
# 16640                                                0.0
#
#        Two or More Races, percent  Hispanic or Latino, percent  \
# 117                           7.1                          6.6
# 276                           2.7                         28.0
# 280                           2.3                         19.6
# 284                           3.1                         25.8
# 288                           2.2                         23.3
# ...                           ...                          ...
# 14534                         0.7                          0.7
# 14538                         0.7                          0.6
# 14590                         1.6                          3.2
# 15592                         1.8                          1.7
# 16640                         1.6                          1.4
#
#        White alone, not Hispanic or Latino, percent          state  \
# 117                                            62.5         Alaska
# 276                                            26.7       New York
# 280                                            36.0       New York
# 284                                            47.5       New York
# 288                                            55.7       New York
# ...                                             ...            ...
# 14534                                          98.0  West Virginia
# 14538                                          98.2  West Virginia
# 14590                                          91.6  New Hampshire
# 15592                                          93.8        Vermont
# 16640                                          94.0          Maine
#
#          loc_winner  total_votes state_abbr  won_loc_and_state  \
# 117    Donald Trump       8081.0         AK               True
# 276       Joe Biden     569038.0         NY               True
# 280       Joe Biden     703310.0         NY               True
# 284       Joe Biden     603040.0         NY               True
# 288       Joe Biden     312371.0         NY               True
# ...             ...          ...        ...                ...
# 14534  Donald Trump       3226.0         WV               True
# 14538  Donald Trump       6012.0         WV               True
# 14590  Donald Trump       2420.0         NH              False
# 15592     Joe Biden        406.0         VT               True
# 16640  Donald Trump        150.0         ME              False
#
#        candidatevotes  totalvotes  win_ratio  state_DI   DI_diff
# 117          189951.0    359530.0   0.528331  0.573340  0.000000
# 276         5230985.0   8661735.0   0.603919  0.600981  0.141243
# 280         5230985.0   8661735.0   0.603919  0.600981  0.091368
# 284         5230985.0   8661735.0   0.603919  0.600981  0.057224
# 288         5230985.0   8661735.0   0.603919  0.600981  0.004930
# ...               ...         ...        ...       ...       ...
# 14534        545382.0    794652.0   0.686316  0.138886 -0.099401
# 14538        545382.0    794652.0   0.686316  0.138886 -0.103301
# 14590        424921.0    806182.0   0.527078  0.158854  0.000000
# 15592        242820.0    370968.0   0.654558  0.119187  0.000000
# 16640        435072.0    828305.0   0.525256  0.115582  0.000000
#
# [3047 rows x 19 columns]

# %% [markdown]
# Clean unemployment_df to merge with merged_counties.

# %%
unemployment_df.drop(columns = ['Series ID', 'Region Code', '2017'], inplace=True)
unemployment_df.drop(unemployment_df.iloc[:, 1:-2], inplace=True, axis = 1)
unemployment_df.rename({'Region Name':'Location', '2016':'2016_unemployment', '2018':'2018_unemployment'}, inplace=True, axis=1)

# %%
merged_counties = merged_counties.merge(unemployment_df, how='outer', on='Location')
merged_counties
# Out:
#                     Location    Loc_DI  \
# 0                     Alaska  0.573340
# 1          Queens County, NY  0.742224
# 2           Kings County, NY  0.692349
# 3        New York County, NY  0.658205
# 4     Westchester County, NY  0.605911
# ...                      ...       ...
# 3139        Wolfe County, KY       NaN
# 3140    Worcester County, MA       NaN
# 3141     Yakutat Cty&Bor, AK       NaN
# 3142         York County, ME       NaN
# 3143    Yukon-Koyukuk CA, AK       NaN
#
#       Black or African American alone, percent  \
# 0                                          3.9
# 1                                         20.9
# 2                                         35.4
# 3                                         18.4
# 4                                         15.9
# ...                                        ...
# 3139                                       NaN
# 3140                                       NaN
# 3141                                       NaN
# 3142                                       NaN
# 3143                                       NaN
#
#       American Indian and Alaska Native alone, percent  Asian alone, percent  \
# 0                                                 14.7                   5.8
# 1                                                  1.3                  25.2
# 2                                                  1.0                  11.7
# 3                                                  1.2                  12.1
# 4                                                  0.8                   6.1
# ...                                                ...                   ...
# 3139                                               NaN                   NaN
# 3140                                               NaN                   NaN
# 3141                                               NaN                   NaN
# 3142                                               NaN                   NaN
# 3143                                               NaN                   NaN
#
#       Native Hawaiian and Other Pacific Islander alone, percent  \
# 0                                                   1.2
# 1                                                   0.2
# 2                                                   0.1
# 3                                                   0.2
# 4                                                   0.1
# ...                                                 ...
# 3139                                                NaN
# 3140                                                NaN
# 3141                                                NaN
# 3142                                                NaN
# 3143                                                NaN
#
#       Two or More Races, percent  Hispanic or Latino, percent  \
# 0                            7.1                          6.6
# 1                            2.7                         28.0
# 2                            2.3                         19.6
# 3                            3.1                         25.8
# 4                            2.2                         23.3
# ...                          ...                          ...
# 3139                         NaN                          NaN
# 3140                         NaN                          NaN
# 3141                         NaN                          NaN
# 3142                         NaN                          NaN
# 3143                         NaN                          NaN
#
#       White alone, not Hispanic or Latino, percent     state  ... total_votes  \
# 0                                             62.5    Alaska  ...      8081.0
# 1                                             26.7  New York  ...    569038.0
# 2                                             36.0  New York  ...    703310.0
# 3                                             47.5  New York  ...    603040.0
# 4                                             55.7  New York  ...    312371.0
# ...                                            ...       ...  ...         ...
# 3139                                           NaN       NaN  ...         NaN
# 3140                                           NaN       NaN  ...         NaN
# 3141                                           NaN       NaN  ...         NaN
# 3142                                           NaN       NaN  ...         NaN
# 3143                                           NaN       NaN  ...         NaN
#
#       state_abbr won_loc_and_state candidatevotes  totalvotes  win_ratio  \
# 0             AK              True       189951.0    359530.0   0.528331
# 1             NY              True      5230985.0   8661735.0   0.603919
# 2             NY              True      5230985.0   8661735.0   0.603919
# 3             NY              True      5230985.0   8661735.0   0.603919
# 4             NY              True      5230985.0   8661735.0   0.603919
# ...          ...               ...            ...         ...        ...
# 3139         NaN               NaN            NaN         NaN        NaN
# 3140         NaN               NaN            NaN         NaN        NaN
# 3141         NaN               NaN            NaN         NaN        NaN
# 3142         NaN               NaN            NaN         NaN        NaN
# 3143         NaN               NaN            NaN         NaN        NaN
#
#       state_DI   DI_diff  2016_unemployment  2018_unemployment
# 0     0.573340  0.000000                NaN                NaN
# 1     0.600981  0.141243                4.5                3.5
# 2     0.600981  0.091368                5.3                4.2
# 3     0.600981  0.057224                4.5                3.6
# 4     0.600981  0.004930                4.3                4.1
# ...        ...       ...                ...                ...
# 3139       NaN       NaN                9.9                7.3
# 3140       NaN       NaN                4.1                3.6
# 3141       NaN       NaN                8.6                9.0
# 3142       NaN       NaN                3.4                2.8
# 3143       NaN       NaN               18.0               16.3
#
# [3144 rows x 21 columns]

# %%
merged_counties.loc[merged_counties['Location']==merged_counties['state'], 'total_votes']=merged_counties['candidatevotes']
merged_counties.rename(mapper={'total_votes':'candidate_votes', 'candidatevotes':'candidate_votes_state', 'totalvotes':'total_votes_state'}, axis=1, inplace=True)

# %%
merged_counties[merged_counties['2016_unemployment'].isnull()]
# Out:
#                    Location    Loc_DI  \
# 0                    Alaska  0.573340
# 1206          Massachusetts  0.414346
# 1578  Broomfield County, CO  0.375931
# 2745            Connecticut  0.478890
# 2846           Rhode Island  0.407071
# 3044          New Hampshire  0.158854
# 3045                Vermont  0.119187
# 3046                  Maine  0.115582
# 3054       Bedford city, VA       NaN
# 3122     Shannon County, SD       NaN
# 3131    Wade Hampton CA, AK       NaN
#
#       Black or African American alone, percent  \
# 0                                          3.9
# 1206                                       8.1
# 1578                                       1.5
# 2745                                      11.3
# 2846                                       7.5
# 3044                                       1.5
# 3045                                       1.2
# 3046                                       1.4
# 3054                                       NaN
# 3122                                       NaN
# 3131                                       NaN
#
#       American Indian and Alaska Native alone, percent  Asian alone, percent  \
# 0                                                 14.7                   5.8
# 1206                                               0.5                   6.0
# 1578                                               0.9                   5.9
# 2745                                               0.5                   4.3
# 2846                                               0.9                   3.3
# 3044                                               0.3                   2.4
# 3045                                               0.4                   1.4
# 3046                                               0.7                   1.1
# 3054                                               NaN                   NaN
# 3122                                               NaN                   NaN
# 3131                                               NaN                   NaN
#
#       Native Hawaiian and Other Pacific Islander alone, percent  \
# 0                                                   1.2
# 1206                                                0.1
# 1578                                                0.1
# 2745                                                0.1
# 2846                                                0.2
# 3044                                                0.0
# 3045                                                0.0
# 3046                                                0.0
# 3054                                                NaN
# 3122                                                NaN
# 3131                                                NaN
#
#       Two or More Races, percent  Hispanic or Latino, percent  \
# 0                            7.1                          6.6
# 1206                         2.1                         10.5
# 1578                         2.6                         12.6
# 2745                         2.1                         14.7
# 2846                         2.5                         13.6
# 3044                         1.6                          3.2
# 3045                         1.8                          1.7
# 3046                         1.6                          1.4
# 3054                         NaN                          NaN
# 3122                         NaN                          NaN
# 3131                         NaN                          NaN
#
#       White alone, not Hispanic or Latino, percent          state  ...  \
# 0                                             62.5         Alaska  ...
# 1206                                          75.1  Massachusetts  ...
# 1578                                          77.7       Colorado  ...
# 2745                                          69.6    Connecticut  ...
# 2846                                          75.3   Rhode Island  ...
# 3044                                          91.6  New Hampshire  ...
# 3045                                          93.8        Vermont  ...
# 3046                                          94.0          Maine  ...
# 3054                                           NaN            NaN  ...
# 3122                                           NaN            NaN  ...
# 3131                                           NaN            NaN  ...
#
#      candidate_votes  state_abbr won_loc_and_state candidate_votes_state  \
# 0           189951.0          AK              True              189951.0
# 1206       2382202.0          MA              True             2382202.0
# 1578         29077.0          CO              True             1804352.0
# 2745       1080831.0          CT              True             1080831.0
# 2846        307486.0          RI              True              307486.0
# 3044        424921.0          NH             False              424921.0
# 3045        242820.0          VT              True              242820.0
# 3046        435072.0          ME             False              435072.0
# 3054             NaN         NaN               NaN                   NaN
# 3122             NaN         NaN               NaN                   NaN
# 3131             NaN         NaN               NaN                   NaN
#
#       total_votes_state  win_ratio  state_DI   DI_diff  2016_unemployment  \
# 0              359530.0   0.528331  0.573340  0.000000                NaN
# 1206          3658005.0   0.651230  0.414346  0.000000                NaN
# 1578          3279980.0   0.550111  0.470384 -0.094453                NaN
# 2745          1823857.0   0.592607  0.478890  0.000000                NaN
# 2846           516990.0   0.594762  0.407071  0.000000                NaN
# 3044           806182.0   0.527078  0.158854  0.000000                NaN
# 3045           370968.0   0.654558  0.119187  0.000000                NaN
# 3046           828305.0   0.525256  0.115582  0.000000                NaN
# 3054                NaN        NaN       NaN       NaN                NaN
# 3122                NaN        NaN       NaN       NaN                NaN
# 3131                NaN        NaN       NaN       NaN                NaN
#
#       2018_unemployment
# 0                   NaN
# 1206                NaN
# 1578                NaN
# 2745                NaN
# 2846                NaN
# 3044                NaN
# 3045                NaN
# 3046                NaN
# 3054                NaN
# 3122                NaN
# 3131                NaN
#
# [11 rows x 21 columns]

# %% [markdown]
# Fill overall states' unemployment data from outside data source.

# %%
merged_counties.loc[merged_counties['Location']=='Alaska', ['2016_unemployment', '2018_unemployment']]=[6.6, 5.9]
merged_counties.loc[merged_counties['Location']=='Massachusetts', ['2016_unemployment', '2018_unemployment']]=[4.0, 3.4]
merged_counties.loc[merged_counties['Location']=='Connecticut', ['2016_unemployment', '2018_unemployment']]=[4.8, 3.9]
merged_counties.loc[merged_counties['Location']=='Rhode Island', ['2016_unemployment', '2018_unemployment']]=[5.2, 4.1]
merged_counties.loc[merged_counties['Location']=='New Hampshire', ['2016_unemployment', '2018_unemployment']]=[2.9, 2.6]
merged_counties.loc[merged_counties['Location']=='Vermont', ['2016_unemployment', '2018_unemployment']]=[3.1, 2.6]
merged_counties.loc[merged_counties['Location']=='Maine', ['2016_unemployment', '2018_unemployment']]=[3.8, 3.1]

# %%
merged_counties.dropna(inplace=True)

# %% [markdown]
# # EDA - Exploratory analysis & creating additional features.

# %% [markdown]
# Create new column of the difference in unemployment rates from 2016-2018.

# %%
merged_counties['unemployment_diff'] = merged_counties['2018_unemployment'] - merged_counties['2016_unemployment']

# %%
merged_counties['loc_winner'].value_counts()
# Out:
# Donald Trump    2561
# Joe Biden        485
# Name: loc_winner, dtype: int64

# %%
fig, axs = plt.subplots(2,2, figsize=(16,16))

axs[0,0].set_title('State vs. County Diversity Index')
axs[0,0].set_xlabel('State Diversity Index')
axs[0,0].set_ylabel('County Diversity Index')
sns.set_style('darkgrid')
sns.scatterplot(ax=axs[0,0], x='state_DI', y='Loc_DI', hue='loc_winner', data=merged_counties, alpha = 0.5, palette=['red', 'blue'], size='candidate_votes');

axs[0,1].set_title('Percent of County Black or African American vs. County Diversity Index')
axs[0,1].set_xlabel('Percent Black or African American')
axs[0,1].set_ylabel('County Diversity Index')
sns.scatterplot(ax=axs[0,1], x='Black or African American alone, percent', y='state_DI', hue='loc_winner', data=merged_counties, alpha = 0.5, palette=['red', 'blue'], size='candidate_votes');

axs[1,0].set_title('Percent of County Hispanic or Latino vs. County Diversity Index')
axs[1,0].set_xlabel('Percent Hispanice or Latino')
axs[1,0].set_ylabel('County Diversity Index')
sns.scatterplot(ax=axs[1,0], x='Hispanic or Latino, percent', y='state_DI', hue='loc_winner', data=merged_counties, alpha = 0.5, palette=['red', 'blue'], size='candidate_votes');

# %%
merged_counties.head()
# Out:
#                  Location    Loc_DI  Black or African American alone, percent  \
# 0                  Alaska  0.573340                                       3.9
# 1       Queens County, NY  0.742224                                      20.9
# 2        Kings County, NY  0.692349                                      35.4
# 3     New York County, NY  0.658205                                      18.4
# 4  Westchester County, NY  0.605911                                      15.9
#
#    American Indian and Alaska Native alone, percent  Asian alone, percent  \
# 0                                              14.7                   5.8
# 1                                               1.3                  25.2
# 2                                               1.0                  11.7
# 3                                               1.2                  12.1
# 4                                               0.8                   6.1
#
#    Native Hawaiian and Other Pacific Islander alone, percent  \
# 0                                                1.2
# 1                                                0.2
# 2                                                0.1
# 3                                                0.2
# 4                                                0.1
#
#    Two or More Races, percent  Hispanic or Latino, percent  \
# 0                         7.1                          6.6
# 1                         2.7                         28.0
# 2                         2.3                         19.6
# 3                         3.1                         25.8
# 4                         2.2                         23.3
#
#    White alone, not Hispanic or Latino, percent     state  ... state_abbr  \
# 0                                          62.5    Alaska  ...         AK
# 1                                          26.7  New York  ...         NY
# 2                                          36.0  New York  ...         NY
# 3                                          47.5  New York  ...         NY
# 4                                          55.7  New York  ...         NY
#
#    won_loc_and_state candidate_votes_state total_votes_state  win_ratio  \
# 0               True              189951.0          359530.0   0.528331
# 1               True             5230985.0         8661735.0   0.603919
# 2               True             5230985.0         8661735.0   0.603919
# 3               True             5230985.0         8661735.0   0.603919
# 4               True             5230985.0         8661735.0   0.603919
#
#    state_DI   DI_diff  2016_unemployment  2018_unemployment  unemployment_diff
# 0  0.573340  0.000000                6.6                5.9               -0.7
# 1  0.600981  0.141243                4.5                3.5               -1.0
# 2  0.600981  0.091368                5.3                4.2               -1.1
# 3  0.600981  0.057224                4.5                3.6               -0.9
# 4  0.600981  0.004930                4.3                4.1               -0.2
#
# [5 rows x 22 columns]

# %%
merged_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3046 entries, 0 to 3046
# Data columns (total 22 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Location                                                   3046 non-null   object
#  1   Loc_DI                                                     3046 non-null   float64
#  2   Black or African American alone, percent                   3046 non-null   float64
#  3   American Indian and Alaska Native alone, percent           3046 non-null   float64
#  4   Asian alone, percent                                       3046 non-null   float64
#  5   Native Hawaiian and Other Pacific Islander alone, percent  3046 non-null   float64
#  6   Two or More Races, percent                                 3046 non-null   float64
#  7   Hispanic or Latino, percent                                3046 non-null   float64
#  8   White alone, not Hispanic or Latino, percent               3046 non-null   float64
#  9   state                                                      3046 non-null   object
#  10  loc_winner                                                 3046 non-null   object
#  11  candidate_votes                                            3046 non-null   float64
#  12  state_abbr                                                 3046 non-null   object
#  13  won_loc_and_state                                          3046 non-null   object
#  14  candidate_votes_state                                      3046 non-null   float64
#  15  total_votes_state                                          3046 non-null   float64
#  16  win_ratio                                                  3046 non-null   float64
#  17  state_DI                                                   3046 non-null   float64
#  18  DI_diff                                                    3046 non-null   float64
#  19  2016_unemployment                                          3046 non-null   float64
#  20  2018_unemployment                                          3046 non-null   float64
#  21  unemployment_diff                                          3046 non-null   float64
# dtypes: float64(17), object(5)
# memory usage: 547.3+ KB

# %%
merged_counties.columns
# Out:
# Index(['Location', 'Loc_DI', 'Black or African American alone, percent',
#        'American Indian and Alaska Native alone, percent',
#        'Asian alone, percent',
#        'Native Hawaiian and Other Pacific Islander alone, percent',
#        'Two or More Races, percent', 'Hispanic or Latino, percent',
#        'White alone, not Hispanic or Latino, percent', 'state', 'loc_winner',
#        'candidate_votes', 'state_abbr', 'won_loc_and_state',
#        'candidate_votes_state', 'total_votes_state', 'win_ratio', 'state_DI',
#        'DI_diff', '2016_unemployment', '2018_unemployment',
#        'unemployment_diff'],
#       dtype='object')

# %%
merged_counties.loc_winner.value_counts()
# Out:
# Donald Trump    2561
# Joe Biden        485
# Name: loc_winner, dtype: int64

# %%
merged_counties.drop('state', axis =1, inplace=True)

# %%
merged_counties.rename(mapper={'loc_winner':'target'}, axis=1, inplace=True)

# %%
target_dict = {'Donald Trump':0, 'Joe Biden':1}
merged_counties['target'] = merged_counties['target'].map(target_dict)

# %%
merged_counties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3046 entries, 0 to 3046
# Data columns (total 21 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Location                                                   3046 non-null   object
#  1   Loc_DI                                                     3046 non-null   float64
#  2   Black or African American alone, percent                   3046 non-null   float64
#  3   American Indian and Alaska Native alone, percent           3046 non-null   float64
#  4   Asian alone, percent                                       3046 non-null   float64
#  5   Native Hawaiian and Other Pacific Islander alone, percent  3046 non-null   float64
#  6   Two or More Races, percent                                 3046 non-null   float64
#  7   Hispanic or Latino, percent                                3046 non-null   float64
#  8   White alone, not Hispanic or Latino, percent               3046 non-null   float64
#  9   target                                                     3046 non-null   int64
#  10  candidate_votes                                            3046 non-null   float64
#  11  state_abbr                                                 3046 non-null   object
#  12  won_loc_and_state                                          3046 non-null   object
#  13  candidate_votes_state                                      3046 non-null   float64
#  14  total_votes_state                                          3046 non-null   float64
#  15  win_ratio                                                  3046 non-null   float64
#  16  state_DI                                                   3046 non-null   float64
#  17  DI_diff                                                    3046 non-null   float64
#  18  2016_unemployment                                          3046 non-null   float64
#  19  2018_unemployment                                          3046 non-null   float64
#  20  unemployment_diff                                          3046 non-null   float64
# dtypes: float64(17), int64(1), object(3)
# memory usage: 523.5+ KB

# %%
merged_counties['state_abbr'].value_counts()
# Out:
# TX    254
# GA    159
# VA    133
# KY    119
# MO    115
# KS    105
# IL    102
# NC    100
# IA     99
# TN     95
# NE     93
# IN     92
# OH     88
# MN     87
# MI     82
# MS     82
# OK     77
# AR     75
# WI     72
# PA     67
# AL     67
# FL     67
# SD     65
# LA     63
# CO     63
# NY     62
# CA     58
# MT     56
# WV     55
# ND     53
# SC     46
# ID     44
# WA     39
# OR     36
# NM     32
# UT     29
# MD     24
# WY     23
# NJ     21
# NV     17
# AZ     15
# HI      4
# DE      3
# CT      1
# VT      1
# DC      1
# NH      1
# MA      1
# RI      1
# ME      1
# AK      1
# Name: state_abbr, dtype: int64

# %%
#Get indices of each state only containing state-level data
single_states = ['AK', 'CT', 'NH', 'MA', 'DC', 'ME', 'RI', 'VT']
indices = []
for state in single_states:
    indices.append(merged_counties[merged_counties['state_abbr']==state].index[0])
indices
# Out:
# [0, 2745, 3044, 1206, 1501, 3046, 2846, 3045]

# %%
#Drop the states that only have state-level data since it will make oversampling difficult in the modeling process
merged_counties.drop(index=indices, inplace=True)
merged_counties['state_abbr'].value_counts()
# Out:
# TX    254
# GA    159
# VA    133
# KY    119
# MO    115
# KS    105
# IL    102
# NC    100
# IA     99
# TN     95
# NE     93
# IN     92
# OH     88
# MN     87
# MI     82
# MS     82
# OK     77
# AR     75
# WI     72
# PA     67
# AL     67
# FL     67
# SD     65
# LA     63
# CO     63
# NY     62
# CA     58
# MT     56
# WV     55
# ND     53
# SC     46
# ID     44
# WA     39
# OR     36
# NM     32
# UT     29
# MD     24
# WY     23
# NJ     21
# NV     17
# AZ     15
# HI      4
# DE      3
# Name: state_abbr, dtype: int64

# %% [markdown]
# Below plot shows the distribution of counties won by each major candidate. Population size is not taken into account.

# %%
fig, ax = plt.subplots(figsize=(16,10))
sns.histplot(x='state_abbr', data=merged_counties, hue='target', palette=['red', 'blue'], multiple='stack')
# Out:
# <AxesSubplot:xlabel='state_abbr', ylabel='Count'>

# %%
#Import Social Vulnerability Index dataset

svi_df = pd.read_csv('data/SVI2018_US_COUNTY.csv')
svi_df.head()
# Out:
#    ST       STATE ST_ABBR      COUNTY   FIPS                       LOCATION  \
# 0  35  NEW MEXICO      NM  Rio Arriba  35039  Rio Arriba County, New Mexico
# 1   1     ALABAMA      AL     Autauga   1001        Autauga County, Alabama
# 2   1     ALABAMA      AL      Blount   1009         Blount County, Alabama
# 3   1     ALABAMA      AL      Butler   1013         Butler County, Alabama
# 4   1     ALABAMA      AL     Calhoun   1015        Calhoun County, Alabama
#
#      AREA_SQMI  E_TOTPOP  M_TOTPOP   E_HU  ...  F_CROWD  F_NOVEH  F_GROUPQ  \
# 0  5860.869195     39307         0  20044  ...        0        0         0
# 1   594.443459     55200         0  23315  ...        0        0         0
# 2   644.830460     57645         0  24222  ...        0        0         0
# 3   776.838201     20025         0  10026  ...        0        0         0
# 4   605.867251    115098         0  53682  ...        0        0         0
#
#    F_THEME4  F_TOTAL  E_UNINSUR  M_UNINSUR  EP_UNINSUR  MP_UNINSUR  E_DAYPOP
# 0         1     -999       4160        588        10.6         1.5     32290
# 1         0        0       3875        508         7.1         0.9     37301
# 2         0        0       6303        732        11.0         1.3     40036
# 3         0        0       2005        340        10.2         1.7     17280
# 4         0        0      10686        796         9.4         0.7    117894
#
# [5 rows x 123 columns]

# %%
svi_df.columns
# Out:
# Index(['ST', 'STATE', 'ST_ABBR', 'COUNTY', 'FIPS', 'LOCATION', 'AREA_SQMI',
#        'E_TOTPOP', 'M_TOTPOP', 'E_HU',
#        ...
#        'F_CROWD', 'F_NOVEH', 'F_GROUPQ', 'F_THEME4', 'F_TOTAL', 'E_UNINSUR',
#        'M_UNINSUR', 'EP_UNINSUR', 'MP_UNINSUR', 'E_DAYPOP'],
#       dtype='object', length=123)

# %% [markdown]
# Subset only the category summary columns from the SVI data.

# %%
svi_themes = svi_df.filter(items=['LOCATION', 'AREA_SQMI', 'E_TOTPOP', 'RPL_THEME1', 'RPL_THEME2', 'RPL_THEME3', 'RPL_THEME4', 'RPL_THEMES'], axis=1)

# %%
svi_themes
# Out:
#                            LOCATION    AREA_SQMI  E_TOTPOP  RPL_THEME1  \
# 0     Rio Arriba County, New Mexico  5860.869195     39307   -999.0000
# 1           Autauga County, Alabama   594.443459     55200      0.3631
# 2            Blount County, Alabama   644.830460     57645      0.6143
# 3            Butler County, Alabama   776.838201     20025      0.8455
# 4           Calhoun County, Alabama   605.867251    115098      0.7866
# ...                             ...          ...       ...         ...
# 3137            Duval County, Texas  1793.476183     11355      0.9825
# 3138           Zapata County, Texas   998.411980     14369      0.9962
# 3139           Zavala County, Texas  1297.406535     12131      0.9847
# 3140           Dimmit County, Texas  1328.884075     10663      0.9946
# 3141         Jim Hogg County, Texas  1136.172598      5282      0.9838
#
#       RPL_THEME2  RPL_THEME3  RPL_THEME4  RPL_THEMES
# 0         0.8758      0.9268      0.5409   -999.0000
# 1         0.5810      0.5947      0.3741      0.4354
# 2         0.3187      0.5915      0.1741      0.4242
# 3         0.9077      0.6447      0.6259      0.8653
# 4         0.8303      0.6507      0.6492      0.8252
# ...          ...         ...         ...         ...
# 3137      0.9990      0.9809      0.8978      0.9994
# 3138      0.9452      0.9990      0.6966      0.9895
# 3139      0.9857      0.9917      0.9331      0.9987
# 3140      0.9936      0.9904      0.9316      0.9997
# 3141      0.9994      0.9793      0.4919      0.9917
#
# [3142 rows x 8 columns]

# %%
#Function to reformat location name so it matches the merged_counties location name
def reformat_location(locations):
    reformatted = []    
    for location in locations:
        location = location.split(', ')
        new_location = location[0] + ', ' + states_dict[location[1]]
        reformatted.append(new_location)
    return reformatted

# %%
svi_themes['LOCATION'] = reformat_location(svi_themes['LOCATION'])
svi_themes
# Out:
#                    LOCATION    AREA_SQMI  E_TOTPOP  RPL_THEME1  RPL_THEME2  \
# 0     Rio Arriba County, NM  5860.869195     39307   -999.0000      0.8758
# 1        Autauga County, AL   594.443459     55200      0.3631      0.5810
# 2         Blount County, AL   644.830460     57645      0.6143      0.3187
# 3         Butler County, AL   776.838201     20025      0.8455      0.9077
# 4        Calhoun County, AL   605.867251    115098      0.7866      0.8303
# ...                     ...          ...       ...         ...         ...
# 3137       Duval County, TX  1793.476183     11355      0.9825      0.9990
# 3138      Zapata County, TX   998.411980     14369      0.9962      0.9452
# 3139      Zavala County, TX  1297.406535     12131      0.9847      0.9857
# 3140      Dimmit County, TX  1328.884075     10663      0.9946      0.9936
# 3141    Jim Hogg County, TX  1136.172598      5282      0.9838      0.9994
#
#       RPL_THEME3  RPL_THEME4  RPL_THEMES
# 0         0.9268      0.5409   -999.0000
# 1         0.5947      0.3741      0.4354
# 2         0.5915      0.1741      0.4242
# 3         0.6447      0.6259      0.8653
# 4         0.6507      0.6492      0.8252
# ...          ...         ...         ...
# 3137      0.9809      0.8978      0.9994
# 3138      0.9990      0.6966      0.9895
# 3139      0.9917      0.9331      0.9987
# 3140      0.9904      0.9316      0.9997
# 3141      0.9793      0.4919      0.9917
#
# [3142 rows x 8 columns]

# %% [markdown]
# Merge the merged_counties dataframe with the SVI dataframe.

# %%
merged_svi = merged_counties.merge(svi_themes, how='outer', left_on='Location', right_on='LOCATION')

# %%
merged_svi.isnull().sum()
# Out:
# Location                                                     104
# Loc_DI                                                       104
# Black or African American alone, percent                     104
# American Indian and Alaska Native alone, percent             104
# Asian alone, percent                                         104
# Native Hawaiian and Other Pacific Islander alone, percent    104
# Two or More Races, percent                                   104
# Hispanic or Latino, percent                                  104
# White alone, not Hispanic or Latino, percent                 104
# target                                                       104
# candidate_votes                                              104
# state_abbr                                                   104
# won_loc_and_state                                            104
# candidate_votes_state                                        104
# total_votes_state                                            104
# win_ratio                                                    104
# state_DI                                                     104
# DI_diff                                                      104
# 2016_unemployment                                            104
# 2018_unemployment                                            104
# unemployment_diff                                            104
# LOCATION                                                       0
# AREA_SQMI                                                      0
# E_TOTPOP                                                       0
# RPL_THEME1                                                     0
# RPL_THEME2                                                     0
# RPL_THEME3                                                     0
# RPL_THEME4                                                     0
# RPL_THEMES                                                     0
# dtype: int64

# %% [markdown]
# Drop null values that correspond to the states in the merged_counties dataframe that had to be dropped in previous steps.

# %%
merged_svi.dropna(inplace=True)

# %%
merged_svi.describe()
# Out:
#             Loc_DI  Black or African American alone, percent  \
# count  3038.000000                               3038.000000
# mean      0.299000                                  9.383937
# std       0.181340                                 14.605913
# min       0.021816                                  0.000000
# 25%       0.127865                                  0.700000
# 50%       0.267307                                  2.400000
# 75%       0.472151                                 11.100000
# max       0.742224                                 85.300000
#
#        American Indian and Alaska Native alone, percent  Asian alone, percent  \
# count                                       3038.000000           3038.000000
# mean                                           1.957571              1.286801
# std                                            6.431943              2.494632
# min                                            0.000000              0.000000
# 25%                                            0.300000              0.400000
# 50%                                            0.600000              0.600000
# 75%                                            1.200000              1.200000
# max                                           86.500000             42.600000
#
#        Native Hawaiian and Other Pacific Islander alone, percent  \
# count                                        3038.000000
# mean                                            0.098980
# std                                             0.408377
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.100000
# max                                            12.700000
#
#        Two or More Races, percent  Hispanic or Latino, percent  \
# count                 3038.000000                  3038.000000
# mean                     1.800889                     8.966195
# std                      1.366723                    13.534556
# min                      0.000000                     0.200000
# 25%                      1.100000                     2.000000
# 50%                      1.500000                     3.800000
# 75%                      2.100000                     9.100000
# max                     29.500000                    95.700000
#
#        White alone, not Hispanic or Latino, percent       target  \
# count                                   3038.000000  3038.000000
# mean                                      77.472219     0.157999
# std                                       19.621241     0.364800
# min                                        3.200000     0.000000
# 25%                                       65.900000     0.000000
# 50%                                       84.800000     0.000000
# 75%                                       93.300000     0.000000
# max                                       98.900000     1.000000
#
#        candidate_votes  ...  2016_unemployment  2018_unemployment  \
# count     3.038000e+03  ...        3038.000000        3038.000000
# mean      3.098451e+04  ...           5.224259           4.113232
# std       9.733546e+04  ...           1.821590           1.373011
# min       6.000000e+01  ...           1.700000           1.400000
# 25%       3.785750e+03  ...           4.000000           3.200000
# 50%       8.349500e+03  ...           4.900000           3.900000
# 75%       2.098900e+04  ...           6.100000           4.800000
# max       3.028885e+06  ...          23.600000          17.500000
#
#        unemployment_diff     AREA_SQMI      E_TOTPOP   RPL_THEME1  \
# count        3038.000000   3038.000000  3.038000e+03  3038.000000
# mean           -1.111027    951.788807  1.008502e+05     0.177668
# std             0.799547   1308.231877  3.316582e+05    18.136198
# min            -6.300000      2.046443  1.020000e+02  -999.000000
# 25%            -1.500000    430.613298  1.094800e+04     0.260875
# 50%            -1.000000    609.199740  2.537200e+04     0.509400
# 75%            -0.600000    914.444380  6.627925e+04     0.754725
# max             2.100000  20059.889101  1.009805e+07     1.000000
#
#         RPL_THEME2   RPL_THEME3   RPL_THEME4   RPL_THEMES
# count  3038.000000  3038.000000  3038.000000  3038.000000
# mean      0.506507     0.499869     0.496677     0.175135
# std       0.287385     0.288682     0.288612    18.136174
# min       0.000000     0.000000     0.000000  -999.000000
# 25%       0.260175     0.251200     0.246175     0.255800
# 50%       0.507650     0.500000     0.494550     0.505900
# 75%       0.755425     0.749025     0.745750     0.753725
# max       1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 25 columns]

# %%
#Identify where the unknown values are
merged_svi[merged_svi['RPL_THEME1']==-999]
# Out:
#                    Location    Loc_DI  \
# 1297  Rio Arriba County, NM  0.439907
#
#       Black or African American alone, percent  \
# 1297                                       0.9
#
#       American Indian and Alaska Native alone, percent  Asian alone, percent  \
# 1297                                              18.0                   0.8
#
#       Native Hawaiian and Other Pacific Islander alone, percent  \
# 1297                                                0.2
#
#       Two or More Races, percent  Hispanic or Latino, percent  \
# 1297                         1.8                         71.4
#
#       White alone, not Hispanic or Latino, percent  target  ...  \
# 1297                                          13.2     1.0  ...
#
#       2018_unemployment unemployment_diff               LOCATION    AREA_SQMI  \
# 1297                5.1              -2.4  Rio Arriba County, NM  5860.869195
#
#       E_TOTPOP  RPL_THEME1  RPL_THEME2  RPL_THEME3  RPL_THEME4  RPL_THEMES
# 1297     39307      -999.0      0.8758      0.9268      0.5409      -999.0
#
# [1 rows x 29 columns]

# %%
#Drop the row with an unknown value
merged_svi.drop([1297], inplace=True)

# %%
#Double check to make sure all -999's are gone
merged_svi.describe()
# Out:
#             Loc_DI  Black or African American alone, percent  \
# count  3037.000000                               3037.000000
# mean      0.298954                                  9.386730
# std       0.181352                                 14.607507
# min       0.021816                                  0.000000
# 25%       0.127857                                  0.700000
# 50%       0.267249                                  2.400000
# 75%       0.472156                                 11.100000
# max       0.742224                                 85.300000
#
#        American Indian and Alaska Native alone, percent  Asian alone, percent  \
# count                                       3037.000000           3037.000000
# mean                                           1.952288              1.286961
# std                                            6.426408              2.495027
# min                                            0.000000              0.000000
# 25%                                            0.300000              0.400000
# 50%                                            0.600000              0.600000
# 75%                                            1.200000              1.200000
# max                                           86.500000             42.600000
#
#        Native Hawaiian and Other Pacific Islander alone, percent  \
# count                                        3037.000000
# mean                                            0.098946
# std                                             0.408441
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.100000
# max                                            12.700000
#
#        Two or More Races, percent  Hispanic or Latino, percent  \
# count                 3037.000000                  3037.000000
# mean                     1.800889                     8.945637
# std                      1.366948                    13.489262
# min                      0.000000                     0.200000
# 25%                      1.100000                     2.000000
# 50%                      1.500000                     3.800000
# 75%                      2.100000                     9.100000
# max                     29.500000                    95.700000
#
#        White alone, not Hispanic or Latino, percent       target  \
# count                                   3037.000000  3037.000000
# mean                                      77.493382     0.157721
# std                                       19.589763     0.364540
# min                                        3.200000     0.000000
# 25%                                       65.900000     0.000000
# 50%                                       84.800000     0.000000
# 75%                                       93.300000     0.000000
# max                                       98.900000     1.000000
#
#        candidate_votes  ...  2016_unemployment  2018_unemployment  \
# count     3.037000e+03  ...        3037.000000        3037.000000
# mean      3.099109e+04  ...           5.223510           4.112907
# std       9.735081e+04  ...           1.821421           1.373120
# min       6.000000e+01  ...           1.700000           1.400000
# 25%       3.782000e+03  ...           4.000000           3.200000
# 50%       8.345000e+03  ...           4.900000           3.900000
# 75%       2.101400e+04  ...           6.100000           4.800000
# max       3.028885e+06  ...          23.600000          17.500000
#
#        unemployment_diff     AREA_SQMI      E_TOTPOP   RPL_THEME1  \
# count        3037.000000   3037.000000  3.037000e+03  3037.000000
# mean           -1.110603    950.172383  1.008705e+05     0.506669
# std             0.799337   1305.409509  3.317109e+05     0.287159
# min            -6.300000      2.046443  1.020000e+02     0.000000
# 25%            -1.500000    430.603207  1.094800e+04     0.261100
# 50%            -1.000000    609.168335  2.536000e+04     0.509600
# 75%            -0.600000    914.285387  6.629900e+04     0.754800
# max             2.100000  20059.889101  1.009805e+07     1.000000
#
#         RPL_THEME2   RPL_THEME3   RPL_THEME4   RPL_THEMES
# count  3037.000000  3037.000000  3037.000000  3037.000000
# mean      0.506385     0.499729     0.496663     0.504136
# std       0.287354     0.288626     0.288659     0.288568
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.260100     0.251200     0.246100     0.256100
# 50%       0.507500     0.499800     0.494400     0.506100
# 75%       0.755200     0.748800     0.745900     0.753800
# max       1.000000     1.000000     1.000000     1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
# # Modeling

# %% [markdown]
# Starting with a simple logistic regression model and adding complexity.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
#Train test split based on state distribution so that each state is adequately represented in both sets
X = merged_counties.drop(['Location', 'target'], axis=1)
y = merged_counties['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=merged_counties['state_abbr'], random_state=42)

# %%
#Plot heatmap to show collinearity 
fig = plt.figure(figsize=(16,16))
sns.heatmap(X.corr(), vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Import modeling libraries.

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, classification_report, plot_confusion_matrix, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

# %%
y.value_counts()
# Out:
# 0    2558
# 1     480
# Name: target, dtype: int64

# %% [markdown]
# Make a dummy model that predicts the majority class.

# %%
dummy = DummyClassifier(strategy='most_frequent', random_state=42).fit(X_train, y_train)
dummy_pred = dummy.predict(X_test)

# %%
#Function to print out metrics nicely
def evaluation_report(model, X, y):
    y_pred = model.predict(X)
    print(classification_report(y, y_pred))
    plot_confusion_matrix(model, X, y, cmap='GnBu')
    plt.grid(False)

# %%
evaluation_report(dummy, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93       654
#            1       0.00      0.00      0.00       106
#
#     accuracy                           0.86       760
#    macro avg       0.43      0.50      0.46       760
# weighted avg       0.74      0.86      0.80       760

# %% [markdown]
# As expected, no 1's are predicted by the dummy model.

# %% [markdown]
# Create a pipeline for a logistic regression model without oversampling.

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2278 entries, 799 to 2248
# Data columns (total 19 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Loc_DI                                                     2278 non-null   float64
#  1   Black or African American alone, percent                   2278 non-null   float64
#  2   American Indian and Alaska Native alone, percent           2278 non-null   float64
#  3   Asian alone, percent                                       2278 non-null   float64
#  4   Native Hawaiian and Other Pacific Islander alone, percent  2278 non-null   float64
#  5   Two or More Races, percent                                 2278 non-null   float64
#  6   Hispanic or Latino, percent                                2278 non-null   float64
#  7   White alone, not Hispanic or Latino, percent               2278 non-null   float64
#  8   candidate_votes                                            2278 non-null   float64
#  9   state_abbr                                                 2278 non-null   object
#  10  won_loc_and_state                                          2278 non-null   object
#  11  candidate_votes_state                                      2278 non-null   float64
#  12  total_votes_state                                          2278 non-null   float64
#  13  win_ratio                                                  2278 non-null   float64
#  14  state_DI                                                   2278 non-null   float64
#  15  DI_diff                                                    2278 non-null   float64
#  16  2016_unemployment                                          2278 non-null   float64
#  17  2018_unemployment                                          2278 non-null   float64
#  18  unemployment_diff                                          2278 non-null   float64
# dtypes: float64(17), object(2)
# memory usage: 355.9+ KB

# %% [markdown]
# Identify numerical and categorical columns and segment X train accordingly.

# %%
X_train_nums = X_train.select_dtypes(['float64'])
X_train_cat = X_train.select_dtypes(exclude = ['float64'])

# %% [markdown]
# Create pipelines for each the numerical and categorical features.

# %%
num_pipeline = Pipeline(steps=[
                                ('ss', StandardScaler())
                            ])


cat_pipeline = Pipeline(steps=[
                            ('ohe', OneHotEncoder(drop='first',
                                                 sparse=False))
                            ])


trans = ColumnTransformer(transformers=[
    ('numerical', num_pipeline, X_train_nums.columns),
    ('categorical', cat_pipeline, X_train_cat.columns)
])

# %% [markdown]
# Join into one pipeline for logistic regression.

# %%
lr_pipe = Pipeline(steps=[
    ('trans', trans),
    ('lr', LogisticRegression(penalty = 'none', max_iter = 1000, random_state=42))
])

# %%
lr_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('trans',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['Loc_DI', 'Black or African American alone, percent',
#        'American Indian and Alaska Native alone, percent',
#        'Asian alone, percent',
#        'Native Hawaiian and Other Pacific Islander alone, percent',
#        'Two or More Races, percent', 'Hispanic or Latino, percent',
#        'White alone, n...
#        'candidate_votes_state', 'total_votes_state', 'win_ratio', 'state_DI',
#        'DI_diff', '2016_unemployment', '2018_unemployment',
#        'unemployment_diff'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   Index(['state_abbr', 'won_loc_and_state'], dtype='object'))])),
#                 ('lr',
#                  LogisticRegression(max_iter=1000, penalty='none',
#                                     random_state=42))])

# %%
evaluation_report(lr_pipe, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       654
#            1       0.81      0.71      0.75       106
#
#     accuracy                           0.94       760
#    macro avg       0.88      0.84      0.86       760
# weighted avg       0.93      0.94      0.93       760

# %% [markdown]
# All around performing better than the dummy classifier. The f1-score for the positive class is 75%, which is the metric that I've chosen to use to evaluate.
#
# Next, I'll use SMOTE to oversample since class imbalance is a problem.

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as imbpipeline

# %%
num_pipeline = imbpipeline(steps=[
                                ('ss', StandardScaler())
                            ])

cat_pipeline = imbpipeline(steps=[
                            ('ohe', OneHotEncoder(drop='first',
                                                 sparse=False))
                            ])

trans = ColumnTransformer(transformers=[
    ('numerical', num_pipeline, X_train_nums.columns),
    ('categorical', cat_pipeline, X_train_cat.columns)
])

# %%
lr_scaled_pipe = imbpipeline(steps=[
    ('trans', trans),
    ('sm', SMOTE(random_state=42)),
    ('lr', LogisticRegression(max_iter = 10000, random_state=42))
])

# %%
lr_scaled_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('trans',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['Loc_DI', 'Black or African American alone, percent',
#        'American Indian and Alaska Native alone, percent',
#        'Asian alone, percent',
#        'Native Hawaiian and Other Pacific Islander alone, percent',
#        'Two or More Races, percent', 'Hispanic or Latino, percent',
#        'White alone, n...
#        'candidate_votes_state', 'total_votes_state', 'win_ratio', 'state_DI',
#        'DI_diff', '2016_unemployment', '2018_unemployment',
#        'unemployment_diff'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   Index(['state_abbr', 'won_loc_and_state'], dtype='object'))])),
#                 ('sm', SMOTE(random_state=42)),
#                 ('lr', LogisticRegression(max_iter=10000, random_state=42))])

# %%
evaluation_report(lr_scaled_pipe, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       654
#            1       0.63      0.87      0.73       106
#
#     accuracy                           0.91       760
#    macro avg       0.81      0.89      0.84       760
# weighted avg       0.93      0.91      0.92       760

# %% [markdown]
# Oversampling improved recall for the positive class, but precision declined and f1-score dropped slightly to 73%.

# %% [markdown]
# # Comparing Feature Coefficients

# %% [markdown]
# Next, I'll use the coefficients from this model to pull out insight as to the effect of each feature on the predictions.

# %%
lr_scaled_pipe['lr'].coef_[0]
# Out:
# array([-1.55540361e+00,  2.34637496e+00,  2.61405385e-01,  2.27593351e+00,
#        -6.80617713e-01,  1.30341288e+00,  5.12830784e-01, -2.19437583e+00,
#         1.21533543e+00,  1.24496889e+00, -7.94089181e-01, -5.49074354e-01,
#        -1.39121524e+00, -6.33648343e-01, -2.87892855e-01, -2.94563499e-01,
#         1.48409336e-01, -8.28469341e-01,  1.24356141e+00,  1.53072854e+00,
#         3.17254791e+00,  4.89640578e-01, -1.77061508e+00, -1.83665376e+00,
#         6.43562540e-05, -4.14780220e-01,  1.78845254e+00,  9.93907890e-01,
#        -1.23085028e+00, -1.23895232e+00, -7.03046612e-01, -5.20697147e-01,
#         7.22767271e-01,  6.68291303e-01,  1.26688172e+00, -1.02012108e+00,
#        -7.24144629e-01,  1.34888366e+00, -1.09422938e+00, -6.31248934e-01,
#        -3.20219101e-01,  1.36624302e+00,  2.28089394e+00,  7.61935441e-03,
#         2.18497783e+00, -1.21441806e+00, -3.08492489e+00,  1.86521359e+00,
#         3.28245868e-01, -1.30410104e+00, -5.95258784e-01, -1.83804171e+00,
#        -2.83929721e+00,  1.20493381e+00,  2.29928346e-01,  2.08052361e+00,
#         1.34105889e+00, -8.88439809e-01,  2.38768464e+00,  6.77285847e-01])

# %% [markdown]
# Make a list of column names that were transformed by the One Hot Encoder.

# %%
ohe_cols = list(lr_scaled_pipe.named_steps['trans'].transformers_[1][1]\
   .named_steps['ohe'].get_feature_names(X_train_cat.columns))
ohe_cols
# Out:
# ['state_abbr_AR',
#  'state_abbr_AZ',
#  'state_abbr_CA',
#  'state_abbr_CO',
#  'state_abbr_DE',
#  'state_abbr_FL',
#  'state_abbr_GA',
#  'state_abbr_HI',
#  'state_abbr_IA',
#  'state_abbr_ID',
#  'state_abbr_IL',
#  'state_abbr_IN',
#  'state_abbr_KS',
#  'state_abbr_KY',
#  'state_abbr_LA',
#  'state_abbr_MD',
#  'state_abbr_MI',
#  'state_abbr_MN',
#  'state_abbr_MO',
#  'state_abbr_MS',
#  'state_abbr_MT',
#  'state_abbr_NC',
#  'state_abbr_ND',
#  'state_abbr_NE',
#  'state_abbr_NJ',
#  'state_abbr_NM',
#  'state_abbr_NV',
#  'state_abbr_NY',
#  'state_abbr_OH',
#  'state_abbr_OK',
#  'state_abbr_OR',
#  'state_abbr_PA',
#  'state_abbr_SC',
#  'state_abbr_SD',
#  'state_abbr_TN',
#  'state_abbr_TX',
#  'state_abbr_UT',
#  'state_abbr_VA',
#  'state_abbr_WA',
#  'state_abbr_WI',
#  'state_abbr_WV',
#  'state_abbr_WY',
#  'won_loc_and_state_True']

# %% [markdown]
# Make a list of the numerical columns.

# %%
num_cols = list(X_train_nums.columns)
num_cols
# Out:
# ['Loc_DI',
#  'Black or African American alone, percent',
#  'American Indian and Alaska Native alone, percent',
#  'Asian alone, percent',
#  'Native Hawaiian and Other Pacific Islander alone, percent',
#  'Two or More Races, percent',
#  'Hispanic or Latino, percent',
#  'White alone, not Hispanic or Latino, percent',
#  'candidate_votes',
#  'candidate_votes_state',
#  'total_votes_state',
#  'win_ratio',
#  'state_DI',
#  'DI_diff',
#  '2016_unemployment',
#  '2018_unemployment',
#  'unemployment_diff']

# %% [markdown]
# Combine both column lists into one in the order in which they appear in the coefficient array.

# %%
all_cols = num_cols + ohe_cols

# %% [markdown]
# Plot features against their coefficients.

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.barplot(x=all_cols, y=lr_scaled_pipe['lr'].coef_[0])
plt.xticks(rotation=85, fontsize=13)
plt.tight_layout()

# %% [markdown]
# Above plot shows the coefficients of each feature. Interestingly the first feature, Loc_DI is the diversity index, which when larger, seems to be a better predictor for Donald Trump. This is perhaps due to the fact that diversity is calculated as a mix of each of the categories, so a county with a somewhat homogeneous racial breakdown of any kind would not be considered very diverse by this metric.
#
# While the state_abbr feature data is interesting, and there is some insight to be gleaned as to the state a county belongs to predicting which way that county votes, that can also be determined by more simple EDA. For that reason, in the next model I will drop the state feature and add SVI data.

# %% [markdown]
# # Grid Searching and Cross Validating

# %% [markdown]
# Using gridsearch to optimize parameters and cross-validate.

# %%
#Create grid of parameters and instantiate a GridSearchCV

params = {
    'lr__penalty': ['l1', 'l2'],
    'lr__solver': ['liblinear', 'lbfgs'],
    'lr__C': [1, 100, 1000]
}

lr_cv = GridSearchCV(lr_scaled_pipe, param_grid=params, scoring='f1', n_jobs=-1)

# %%
lr_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('trans',
#                                         ColumnTransformer(transformers=[('numerical',
#                                                                          Pipeline(steps=[('ss',
#                                                                                           StandardScaler())]),
#                                                                          Index(['Loc_DI', 'Black or African American alone, percent',
#        'American Indian and Alaska Native alone, percent',
#        'Asian alone, percent',
#        'Native Hawaiian and Other Pacific Islander alone, percent',
#        'Two or More Races, percent', 'Hispanic or Latino...
#                                                                         ('categorical',
#                                                                          Pipeline(steps=[('ohe',
#                                                                                           OneHotEncoder(drop='first',
#                                                                                                         sparse=False))]),
#                                                                          Index(['state_abbr', 'won_loc_and_state'], dtype='object'))])),
#                                        ('sm', SMOTE(random_state=42)),
#                                        ('lr',
#                                         LogisticRegression(max_iter=10000,
#                                                            random_state=42))]),
#              n_jobs=-1,
#              param_grid={'lr__C': [1, 100, 1000], 'lr__penalty': ['l1', 'l2'],
#                          'lr__solver': ['liblinear', 'lbfgs']},
#              scoring='f1')

# %%
evaluation_report(lr_cv, X_train, y_train)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95      1904
#            1       0.69      0.90      0.78       374
#
#     accuracy                           0.92      2278
#    macro avg       0.84      0.91      0.87      2278
# weighted avg       0.93      0.92      0.92      2278

# %%
evaluation_report(lr_cv, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       654
#            1       0.63      0.87      0.73       106
#
#     accuracy                           0.91       760
#    macro avg       0.81      0.89      0.84       760
# weighted avg       0.93      0.91      0.92       760

# %% [markdown]
# Despite gridsearching, the f1-score remains at 73% which is the same as the original model.

# %% [markdown]
# # Compare Win Ratio to Probability of Classification

# %% [markdown]
# Looking at the probability as a reflection of margin of win.

# %%
ratio_array = X_test['win_ratio'].array

# %%
#Create an array of the higher probability of the two classes for each prediction from X_test

probs = list(lr_cv.predict_proba(X_test))
win_prob = []
for prob in probs:    
    prob0 = prob[0]
    prob1 = prob[1]
    if prob0 > prob1:
        win_prob.append(prob0)
    else:
        win_prob.append(prob1)

win_array = np.array(win_prob)

# %%
#Compute and plot the difference between the predicted probability and actual win ratio 

diff_array = win_array - ratio_array
sns.distplot(diff_array)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# This distribution plot shows that the majority of the time, there's around a 40% difference in the probability and win ratio for this model. That is a pretty wide margin, so it's safe to say the probability prediction is not a great estimator of win margin.

# %% [markdown]
# # Changing the Modeling Data

# %% [markdown]
# Adding SVI data, removing state_abbr.

# %%
X = merged_svi.drop(['Location', 'target', 'state_abbr', 'LOCATION'], axis=1)
y = merged_svi['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=merged_svi['state_abbr'], random_state=42)

# %%
# Make dummy model to predict majority class

dummy = DummyClassifier(strategy='most_frequent', random_state=42).fit(X_train, y_train)
dummy_pred = dummy.predict(X_test)

# %%
evaluation_report(dummy, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      1.00      0.93       654
#          1.0       0.00      0.00      0.00       106
#
#     accuracy                           0.86       760
#    macro avg       0.43      0.50      0.46       760
# weighted avg       0.74      0.86      0.80       760

# %% [markdown]
# As expected, the dummy model only predicts 0's. Next I'll follow the same oversampling and scaling pipelines from the previous model to compare.

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2277 entries, 798 to 2230
# Data columns (total 25 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Loc_DI                                                     2277 non-null   float64
#  1   Black or African American alone, percent                   2277 non-null   float64
#  2   American Indian and Alaska Native alone, percent           2277 non-null   float64
#  3   Asian alone, percent                                       2277 non-null   float64
#  4   Native Hawaiian and Other Pacific Islander alone, percent  2277 non-null   float64
#  5   Two or More Races, percent                                 2277 non-null   float64
#  6   Hispanic or Latino, percent                                2277 non-null   float64
#  7   White alone, not Hispanic or Latino, percent               2277 non-null   float64
#  8   candidate_votes                                            2277 non-null   float64
#  9   won_loc_and_state                                          2277 non-null   object
#  10  candidate_votes_state                                      2277 non-null   float64
#  11  total_votes_state                                          2277 non-null   float64
#  12  win_ratio                                                  2277 non-null   float64
#  13  state_DI                                                   2277 non-null   float64
#  14  DI_diff                                                    2277 non-null   float64
#  15  2016_unemployment                                          2277 non-null   float64
#  16  2018_unemployment                                          2277 non-null   float64
#  17  unemployment_diff                                          2277 non-null   float64
#  18  AREA_SQMI                                                  2277 non-null   float64
#  19  E_TOTPOP                                                   2277 non-null   int64
#  20  RPL_THEME1                                                 2277 non-null   float64
#  21  RPL_THEME2                                                 2277 non-null   float64
#  22  RPL_THEME3                                                 2277 non-null   float64
#  23  RPL_THEME4                                                 2277 non-null   float64
#  24  RPL_THEMES                                                 2277 non-null   float64
# dtypes: float64(23), int64(1), object(1)
# memory usage: 462.5+ KB

# %%
X_train_nums = X_train.select_dtypes(exclude = ['object'])
X_train_cat = X_train.select_dtypes(['object'])

# %%
num_pipeline = imbpipeline(steps=[
                                ('ss', StandardScaler())
                            ])

cat_pipeline = imbpipeline(steps=[
                            ('ohe', OneHotEncoder(drop='first',
                                                 sparse=False))
                            ])

trans = ColumnTransformer(transformers=[
    ('numerical', num_pipeline, X_train_nums.columns),
    ('categorical', cat_pipeline, X_train_cat.columns)
])

# %%
lr_scaled_pipe = imbpipeline(steps=[
    ('trans', trans),
    ('sm', SMOTE(random_state=42)),
    ('lr', LogisticRegression(max_iter = 10000, random_state=42))
])

# %%
lr_scaled_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('trans',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['Loc_DI', 'Black or African American alone, percent',
#        'American Indian and Alaska Native alone, percent',
#        'Asian alone, percent',
#        'Native Hawaiian and Other Pacific Islander alone, percent',
#        'Two or More Races, percent', 'Hispanic or Latino, percent',
#        'White alone, n...
#        'DI_diff', '2016_unemployment', '2018_unemployment',
#        'unemployment_diff', 'AREA_SQMI', 'E_TOTPOP', 'RPL_THEME1',
#        'RPL_THEME2', 'RPL_THEME3', 'RPL_THEME4', 'RPL_THEMES'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   Index(['won_loc_and_state'], dtype='object'))])),
#                 ('sm', SMOTE(random_state=42)),
#                 ('lr', LogisticRegression(max_iter=10000, random_state=42))])

# %%
evaluation_report(lr_scaled_pipe, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.90      0.94       654
#          1.0       0.58      0.85      0.69       106
#
#     accuracy                           0.89       760
#    macro avg       0.78      0.87      0.81       760
# weighted avg       0.92      0.89      0.90       760

# %% [markdown]
# This model has a slightly worse f1-score than the first one, at 69%. However, the feature coefficients may provide additional insight.
#
# Next I will again create a list of all of the columns and plot their coefficients.

# %%
ohe_cols = list(lr_scaled_pipe.named_steps['trans'].transformers_[1][1]\
   .named_steps['ohe'].get_feature_names(X_train_cat.columns))
ohe_cols
# Out:
# ['won_loc_and_state_True']

# %%
num_cols = list(X_train_nums.columns)
num_cols
# Out:
# ['Loc_DI',
#  'Black or African American alone, percent',
#  'American Indian and Alaska Native alone, percent',
#  'Asian alone, percent',
#  'Native Hawaiian and Other Pacific Islander alone, percent',
#  'Two or More Races, percent',
#  'Hispanic or Latino, percent',
#  'White alone, not Hispanic or Latino, percent',
#  'candidate_votes',
#  'candidate_votes_state',
#  'total_votes_state',
#  'win_ratio',
#  'state_DI',
#  'DI_diff',
#  '2016_unemployment',
#  '2018_unemployment',
#  'unemployment_diff',
#  'AREA_SQMI',
#  'E_TOTPOP',
#  'RPL_THEME1',
#  'RPL_THEME2',
#  'RPL_THEME3',
#  'RPL_THEME4',
#  'RPL_THEMES']

# %%
all_cols = num_cols + ohe_cols

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.barplot(x=all_cols, y=lr_scaled_pipe['lr'].coef_[0])
plt.xticks(rotation=80, fontsize=13)
plt.tight_layout()

# %% [markdown]
# The coefficients have changed significantly from the last model. Despite the RPL themes 1-4 not being highly significant predictors for Trump, RPL_THEMES, which is the overall SVI, is a somewhat important predictor for a vote for Trump.

# %% [markdown]
# # Decision Tree

# %% [markdown]
# Using a decision tree model to pull out feature importances.

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
tree_pipe = Pipeline(steps=[
    ('trans', trans),
    ('dtc', DecisionTreeClassifier(class_weight='balanced', random_state=42))
])

# %%
tree_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('trans',
#                  ColumnTransformer(transformers=[('numerical',
#                                                   Pipeline(steps=[('ss',
#                                                                    StandardScaler())]),
#                                                   Index(['Loc_DI', 'Black or African American alone, percent',
#        'American Indian and Alaska Native alone, percent',
#        'Asian alone, percent',
#        'Native Hawaiian and Other Pacific Islander alone, percent',
#        'Two or More Races, percent', 'Hispanic or Latino, percent',
#        'White alone, n...
#        'DI_diff', '2016_unemployment', '2018_unemployment',
#        'unemployment_diff', 'AREA_SQMI', 'E_TOTPOP', 'RPL_THEME1',
#        'RPL_THEME2', 'RPL_THEME3', 'RPL_THEME4', 'RPL_THEMES'],
#       dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  sparse=False))]),
#                                                   Index(['won_loc_and_state'], dtype='object'))])),
#                 ('dtc',
#                  DecisionTreeClassifier(class_weight='balanced',
#                                         random_state=42))])

# %%
evaluation_report(tree_pipe, X_test, y_test)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.92      0.94       654
#          1.0       0.60      0.72      0.66       106
#
#     accuracy                           0.89       760
#    macro avg       0.78      0.82      0.80       760
# weighted avg       0.90      0.89      0.90       760

# %%
importances = tree_pipe['dtc'].feature_importances_

# %%
importance_dict = dict(zip(all_cols, importances))

# %%
fig, ax = plt.subplots(figsize=(8,8))
plt.bar(importance_dict.keys(), importance_dict.values())
plt.xticks(rotation=85, fontsize=13);

# %% [markdown]
# The insight from this decision tree is somewhat in contrast to the coefficients from the previous logistic regression. Here, the top 4 features are RPL_Theme3, percent of population that identifies as solely Asian, percent of population that identifies as solely white, and RPL_Theme2. Themes 2 and 3 correspond to household composition, and minority status/language, respectively.
#
# Seeing that Minority status/language is the most important feature according to this model is quite telling. The theme breakdown includes the percentage of the population that is of a racial minority and the percentage of people that speak English "less than well".
#
# These models work best when we take them as the sum of their parts, since this particular challenge is better suited to qualitative analysis of these features. Though the f1-score of the decision tree is slightly less (66%) than the logistic regression, the feature importances bring the problem into focus.

# %% [markdown]
# # Conclusion and Summary

# %% [markdown]
# I was working with a lot of datasets with a lot of features so the possibilities of different permutations to model are endless. It was challenging to distill all of that information into interpretable results, but overall, these models perform moderately well and identify several important features such as minority status and percentage of the population that is white that have a discernable effect on the predicted winner.
